# %% [markdown]
# ### Install some libs

# %% [markdown]
# !pip install treelib

# %% [markdown]
# !pip3 install tree_sitter

# %% [markdown]
# ### Import some libs

# %%
from treelib import Node, Tree
from tree_sitter import Language, Parser
import os
import numpy as np

# %% [markdown]
# ### Initialize Tree-sitter go parser

# %%
Language.build_library(
  # Store the library in the `build` directory
  'build/my-languages.so',

  # Include one or more languages
  [
    'tree-sitter-go'
  ]
)

GO_LANGUAGE = Language('build/my-languages.so', 'go')

parser = Parser()
parser.set_language(GO_LANGUAGE)

# %% [markdown]
# ## Step I : Find the Feature Toggles (FT)

# %%
keywords = ["CacheNodeidentityInfo", "EnableSeparateConfigBase", "ExperimentalClusterDNS",
            "GoogleCloudBucketACL", "KeepLaunchConfigurations", "SpecOverrideFlag", "Spotinst",
            "SpotinstOcean", "SpotinstHybrid", "SpotinstController", "VFSVaultSupport",
            "VPCSkipEnableDNSSupport", "SkipEtcdVersionCheck", "TerraformJSON", "ClusterAddons",
            "KopsControllerStateStore", "APIServerNodes", "UseAddonOperators", "AWSIPv6",
            "TerraformManagedFiles", "AlphaAllowGCE", "AlphaAllowALI"]
# removing "Azure" because it affects more than 100 files

# %% [markdown]
# ### List files with keywords

# %% [markdown]
# #### List all .go files

# %%
go_folders = [x[0] for x in os.walk("./kops-master/")]

go_files = []
for dir_name in go_folders:
    files = [dir_name+"/"+k for k in os.listdir(dir_name) if k[len(k)-3:] ==".go"]
    go_files.extend(files)

print("10 random .go files in this project :")
for k in range(10):
    print(go_files[np.random.randint(len(go_files))])
# Out:
# 10 random .go files in this project :
# ./kops-master/vendor/github.com/Azure/go-autorest/autorest/azure/metadata_environment.go
# ./kops-master/vendor/k8s.io/client-go/tools/leaderelection/resourcelock/configmaplock.go
# ./kops-master/vendor/github.com/modern-go/reflect2/unsafe_type.go
# ./kops-master/vendor/github.com/digitalocean/godo/action.go
# ./kops-master/vendor/github.com/containerd/containerd/remotes/docker/schema1/converter.go
# ./kops-master/vendor/github.com/Azure/azure-sdk-for-go/services/resources/mgmt/2020-06-01/resources/deployments.go
# ./kops-master/vendor/sigs.k8s.io/kustomize/kyaml/fn/runtime/starlark/doc.go
# ./kops-master/vendor/oras.land/oras-go/pkg/context/context.go
# ./kops-master/vendor/k8s.io/apimachinery/pkg/util/httpstream/httpstream.go
# ./kops-master/vendor/github.com/miekg/dns/nsecx.go

# %%
len(go_files)
# Out:
# 8304

# %% [markdown]
# #### List the interesting files, containing at least one keyword with the featureflag

# %%
go_file_interests = []

for file in go_files:
    s = ""
    with open(file, "r") as f:
        s+=f.read()+"\n"
    kw_file = [k for k in keywords if k in s]
    if len(kw_file) > 0 and "featureflag" in s:
        print(file, "contains :")
        for kw in kw_file:
            print("->",kw)
        go_file_interests.append(file)
        print("\n")
# Out:
# ./kops-master/upup/pkg/fi/cloudup/template_functions.go contains :
# -> CacheNodeidentityInfo
# -> Spotinst
# -> APIServerNodes
#
#
# ./kops-master/upup/pkg/fi/cloudup/apply_cluster.go contains :
# -> Spotinst
# -> SpotinstHybrid
# -> KopsControllerStateStore
# -> TerraformManagedFiles
# -> AlphaAllowGCE
# -> AlphaAllowALI
#
#
# ./kops-master/upup/pkg/fi/cloudup/populate_instancegroup_spec.go contains :
# -> APIServerNodes
#
#
# ./kops-master/upup/pkg/fi/cloudup/new_cluster.go contains :
# -> Spotinst
#
#
# ./kops-master/upup/pkg/fi/cloudup/alitasks/launchconfiguration.go contains :
# -> KeepLaunchConfigurations
#
#
# ./kops-master/upup/pkg/fi/cloudup/terraform/target_hcl2.go contains :
# -> Spotinst
#
#
# ./kops-master/upup/pkg/fi/cloudup/terraform/target.go contains :
# -> TerraformJSON
# -> TerraformManagedFiles
#
#
# ./kops-master/upup/pkg/fi/cloudup/bootstrapchannelbuilder/bootstrapchannelbuilder.go contains :
# -> Spotinst
# -> SpotinstController
# -> ClusterAddons
# -> UseAddonOperators
#
#
# ./kops-master/upup/pkg/fi/cloudup/awsup/aws_cloud.go contains :
# -> Spotinst
# -> SpotinstHybrid
#
#
# ./kops-master/upup/pkg/fi/cloudup/awstasks/vpc.go contains :
# -> VPCSkipEnableDNSSupport
#
#
# ./kops-master/upup/pkg/fi/fitasks/managedfile.go contains :
# -> TerraformManagedFiles
#
#
# ./kops-master/pkg/nodelabels/builder.go contains :
# -> APIServerNodes
#
#
# ./kops-master/pkg/model/gcemodel/storageacl.go contains :
# -> GoogleCloudBucketACL
#
#
# ./kops-master/pkg/model/awsmodel/spotinst.go contains :
# -> Spotinst
# -> SpotinstOcean
# -> SpotinstHybrid
#
#
# ./kops-master/pkg/model/awsmodel/autoscalinggroup.go contains :
# -> Spotinst
# -> SpotinstHybrid
#
#
# ./kops-master/pkg/model/components/etcdmanager/options.go contains :
# -> SkipEtcdVersionCheck
#
#
# ./kops-master/pkg/model/components/etcdmanager/model.go contains :
# -> APIServerNodes
#
#
# ./kops-master/pkg/instancegroups/settings.go contains :
# -> Spotinst
#
#
# ./kops-master/pkg/clouds/supported.go contains :
# -> AlphaAllowGCE
# -> AlphaAllowALI
#
#
# ./kops-master/pkg/resources/aws/aws.go contains :
# -> Spotinst
#
#
# ./kops-master/pkg/wellknownoperators/operators.go contains :
# -> UseAddonOperators
#
#
# ./kops-master/pkg/apis/kops/validation/legacy.go contains :
# -> ExperimentalClusterDNS
# -> VFSVaultSupport
#
#
# ./kops-master/pkg/featureflag/featureflag.go contains :
# -> CacheNodeidentityInfo
# -> EnableSeparateConfigBase
# -> ExperimentalClusterDNS
# -> GoogleCloudBucketACL
# -> KeepLaunchConfigurations
# -> SpecOverrideFlag
# -> Spotinst
# -> SpotinstOcean
# -> SpotinstHybrid
# -> SpotinstController
# -> VFSVaultSupport
# -> VPCSkipEnableDNSSupport
# -> SkipEtcdVersionCheck
# -> TerraformJSON
# -> ClusterAddons
# -> KopsControllerStateStore
# -> APIServerNodes
# -> UseAddonOperators
# -> AWSIPv6
# -> TerraformManagedFiles
# -> AlphaAllowGCE
# -> AlphaAllowALI
#
#
# ./kops-master/cmd/kops/integration_test.go contains :
# -> APIServerNodes
# -> AWSIPv6
# -> AlphaAllowGCE
#
#
# ./kops-master/cmd/kops/lifecycle_integration_test.go contains :
# -> SpecOverrideFlag
# -> AlphaAllowGCE
#
#
# ./kops-master/cmd/kops/edit_cluster.go contains :
# -> SpecOverrideFlag
#
#
# ./kops-master/cmd/kops/create_instancegroup.go contains :
# -> APIServerNodes
#
#
# ./kops-master/cmd/kops/edit_instancegroup.go contains :
# -> SpecOverrideFlag
#
#
# ./kops-master/cmd/kops/create_cluster.go contains :
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
# -> Spotinst
# -> ClusterAddons
# -> APIServerNodes
# -> AWSIPv6
# -> AlphaAllowGCE

# %%
len(go_file_interests)
# Out:
# 29

# %% [markdown]
# ## Step 3 - Search Feature Toggles dependencies in the AST

# %%
for gfi in go_file_interests:
    
    s = ""
    with open(gfi, "r") as f:
        s+=f.read()+"\n"

    print("File :            ", gfi, "\n")

    source = bytes(s, "utf8")
    ast = parser.parse(source)

    root_node = ast.root_node

    tree = Tree()

    root_node = ast.root_node

    type_nodes = dict()

    def get_name(node):
        return source[node.start_byte:node.end_byte].decode('utf8')

    def get_id(node):
        global type_nodes
        node_type = node.type
        if node_type not in type_nodes:
            type_nodes[node_type]=1
        else:
            type_nodes[node_type]+=1
        return node_type+str(type_nodes[node_type])

    def process(root_id, node):
        global tree
        node_id = get_id(node)
        node_name = get_name(node)
        for kw in keywords:
            if kw in node_name and node.type == 'if_statement':
                #print("\n\n"+get_name(node)+"\n\n")
                for c in node.children:
                    if c.type == 'binary_expression' or c.type == 'unary_expression' or c.type == 'call_expression':
                        print("->",get_name(c))
        tree.create_node(node_name,
                         node_id,
                         parent = root_id)
        if len(node.children) != 0:
            for i in range(len(node.children)):
                process(node_id, node.children[i])

    tree.create_node("root", "root")
    for i in range(len(root_node.children)):
        process("root", root_node.children[i])
    print("\n")

    #tree.show()
# Out:
# File :             ./kops-master/upup/pkg/fi/cloudup/template_functions.go
#
# -> featureflag.Spotinst.Enabled()
# -> err == nil
# -> featureflag.APIServerNodes.Enabled()
# -> featureflag.CacheNodeidentityInfo.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/apply_cluster.go
#
# -> !featureflag.AlphaAllowGCE.Enabled()
# -> !featureflag.AlphaAllowALI.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> ok && featureflag.TerraformManagedFiles.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/populate_instancegroup_spec.go
#
# -> ig.IsMaster()
# -> ig.Spec.Role == kops.InstanceGroupRoleBastion
# -> ig.IsAPIServerOnly() && !featureflag.APIServerNodes.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/new_cluster.go
#
# -> featureflag.Spotinst.Enabled()
# -> opt.SpotinstProduct != ""
# -> opt.SpotinstOrientation != ""
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/alitasks/launchconfiguration.go
#
# -> featureflag.KeepLaunchConfigurations.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/terraform/target_hcl2.go
#
# -> t.Cloud.ProviderID() == kops.CloudProviderGCE
# -> t.Cloud.ProviderID() == kops.CloudProviderAWS
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/terraform/target.go
#
# -> featureflag.TerraformJSON.Enabled()
# -> featureflag.TerraformJSON.Enabled()
# -> featureflag.TerraformManagedFiles.Enabled()
# -> featureflag.TerraformManagedFiles.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/bootstrapchannelbuilder/bootstrapchannelbuilder.go
#
# -> featureflag.UseAddonOperators.Enabled()
# -> featureflag.UseAddonOperators.Enabled()
# -> b.ClusterAddons != nil
# -> kubeDNS.Provider == "CoreDNS" && !featureflag.UseAddonOperators.Enabled()
# -> featureflag.Spotinst.Enabled() && featureflag.SpotinstController.Enabled()
# -> featureflag.Spotinst.Enabled() && featureflag.SpotinstController.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/awsup/aws_cloud.go
#
# -> raw == nil
# -> featureflag.Spotinst.Enabled()
# -> c.spotinst != nil
# -> c.spotinst != nil
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> c.spotinst != nil
# -> c.spotinst != nil
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> c.spotinst != nil
# -> c.spotinst != nil
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/cloudup/awstasks/vpc.go
#
# -> changes != nil && changes.EnableDNSSupport != nil
# -> featureflag.VPCSkipEnableDNSSupport.Enabled()
#
#
# File :             ./kops-master/upup/pkg/fi/fitasks/managedfile.go
#
# -> !featureflag.TerraformManagedFiles.Enabled()
#
#
# File :             ./kops-master/pkg/nodelabels/builder.go
#
# -> isAPIServer || isControlPlane
# -> featureflag.APIServerNodes.Enabled()
#
#
# File :             ./kops-master/pkg/model/gcemodel/storageacl.go
#
# -> featureflag.GoogleCloudBucketACL.Enabled()
#
#
# File :             ./kops-master/pkg/model/awsmodel/spotinst.go
#
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstOcean.Enabled()
# -> featureflag.SpotinstOcean.Enabled()
# -> cfg != nil
# -> !featureflag.SpotinstOcean.Enabled()
# -> !featureflag.SpotinstOcean.Enabled()
#
#
# File :             ./kops-master/pkg/model/awsmodel/autoscalinggroup.go
#
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> !featureflag.Spotinst.Enabled() ||
# 		(featureflag.SpotinstHybrid.Enabled() && !HybridInstanceGroup(ig))
# -> !featureflag.Spotinst.Enabled() ||
# 		(featureflag.SpotinstHybrid.Enabled() && !HybridInstanceGroup(ig))
#
#
# File :             ./kops-master/pkg/model/components/etcdmanager/options.go
#
# -> !etcdVersionIsSupported(etcdCluster.Version)
# -> featureflag.SkipEtcdVersionCheck.Enabled()
#
#
# File :             ./kops-master/pkg/model/components/etcdmanager/model.go
#
# -> featureflag.APIServerNodes.Enabled()
# -> featureflag.APIServerNodes.Enabled()
# -> !featureflag.APIServerNodes.Enabled()
#
#
# File :             ./kops-master/pkg/instancegroups/settings.go
#
# -> rollingUpdate.MaxSurge == nil
# -> kops.CloudProviderID(cluster.Spec.CloudProvider) == kops.CloudProviderAWS && !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops-master/pkg/clouds/supported.go
#
# -> featureflag.AlphaAllowALI.Enabled()
# -> featureflag.AlphaAllowGCE.Enabled()
#
#
# File :             ./kops-master/pkg/resources/aws/aws.go
#
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops-master/pkg/wellknownoperators/operators.go
#
# -> !featureflag.UseAddonOperators.Enabled()
#
#
# File :             ./kops-master/pkg/apis/kops/validation/legacy.go
#
# -> c.Spec.KubeDNS != nil
# -> c.Spec.KubeDNS.ServerIP != ""
# -> ip == nil
# -> !featureflag.ExperimentalClusterDNS.Enabled()
# -> isExperimentalClusterDNS(c.Spec.Kubelet, c.Spec.KubeDNS)
# -> isExperimentalClusterDNS(c.Spec.MasterKubelet, c.Spec.KubeDNS)
# -> strings.HasPrefix(c.Spec.SecretStore, "vault://")
# -> !featureflag.VFSVaultSupport.Enabled()
# -> strings.HasPrefix(c.Spec.KeyStore, "vault://")
# -> !featureflag.VFSVaultSupport.Enabled()
#
#
# File :             ./kops-master/pkg/featureflag/featureflag.go
#
#
#
# File :             ./kops-master/cmd/kops/integration_test.go
#
#
#
# File :             ./kops-master/cmd/kops/lifecycle_integration_test.go
#
#
#
# File :             ./kops-master/cmd/kops/edit_cluster.go
#
# -> featureflag.SpecOverrideFlag.Enabled()
#
#
# File :             ./kops-master/cmd/kops/create_instancegroup.go
#
# -> r == kopsapi.InstanceGroupRoleAPIServer && !featureflag.APIServerNodes.Enabled()
#
#
# File :             ./kops-master/cmd/kops/edit_instancegroup.go
#
# -> featureflag.SpecOverrideFlag.Enabled()
#
#
# File :             ./kops-master/cmd/kops/create_cluster.go
#
# -> featureflag.EnableSeparateConfigBase.Enabled()
# -> featureflag.ClusterAddons.Enabled()
# -> featureflag.AWSIPv6.Enabled()
# -> featureflag.SpecOverrideFlag.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> featureflag.APIServerNodes.Enabled()
# -> !options.IPv6
# -> featureflag.AlphaAllowGCE.Enabled() && (options.CloudProvider == "gce" || options.CloudProvider == "")

# %%
type_nodes
# Out:
# {'comment': 18,
#  'package_clause': 1,
#  'package': 1,
#  'package_identifier': 1,
#  '\n': 158,
#  'import_declaration': 1,
#  'import': 1,
#  'import_spec_list': 1,
#  '(': 109,
#  'import_spec': 13,
#  'interpreted_string_literal': 125,
#  '"': 250,
#  ')': 109,
#  'method_declaration': 6,
#  'func': 9,
#  'parameter_list': 17,
#  'parameter_declaration': 11,
#  'identifier': 296,
#  'pointer_type': 6,
#  '*': 7,
#  'type_identifier': 26,
#  'field_identifier': 146,
#  'block': 57,
#  '{': 65,
#  'var_declaration': 2,
#  'var': 2,
#  'var_spec': 2,
#  'call_expression': 88,
#  'selector_expression': 140,
#  '.': 140,
#  'argument_list': 88,
#  'func_literal': 1,
#  'assignment_statement': 29,
#  'expression_list': 158,
#  '=': 29,
#  '}': 65,
#  'return_statement': 26,
#  'return': 26,
#  'if_statement': 42,
#  'if': 42,
#  'short_var_declaration': 30,
#  ':=': 34,
#  ';': 6,
#  'binary_expression': 55,
#  '!=': 20,
#  'nil': 18,
#  ',': 83,
#  '||': 2,
#  'expression_switch_statement': 4,
#  'switch': 4,
#  'expression_case': 10,
#  'case': 10,
#  ':': 18,
#  '==': 21,
#  'int_literal': 14,
#  '&&': 4,
#  'true': 2,
#  'for_statement': 4,
#  'for': 4,
#  'range_clause': 4,
#  'range': 4,
#  'unary_expression': 1,
#  '-': 1,
#  'slice_expression': 6,
#  '[': 16,
#  ']': 16,
#  '+': 6,
#  'else': 4,
#  'default_case': 2,
#  'default': 2,
#  'slice_type': 8,
#  'variadic_argument': 1,
#  'composite_literal': 4,
#  'literal_value': 4,
#  'element': 12,
#  '...': 1,
#  'index_expression': 2,
#  '>': 1,
#  'function_declaration': 2,
#  'type_conversion_expression': 3}

# %%
# Pattern matching -> does not work yet

# %% [markdown]
# query = GO_LANGUAGE.query("""
# (function_definition
#   name: (identifier) @function.def)
#
# (call
#   function: (identifier) @function.call)
# """)
#
# captures = query.captures(tree.root_node)
