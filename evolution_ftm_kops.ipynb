# %% [markdown]
# ### Install some libs

# %% [markdown]
# !pip install treelib

# %% [markdown]
# !pip3 install tree_sitter

# %% [markdown]
# ### Import some libs

# %%
from treelib import Node, Tree
from tree_sitter import Language, Parser
import os
import numpy as np
import regex as re
import subprocess

# %% [markdown]
# ### Initialize Tree-sitter go parser

# %%
Language.build_library(
  # Store the library in the `build` directory
  'build/my-languages.so',

  # Include one or more languages
  [
    'tree-sitter-go'
  ]
)

GO_LANGUAGE = Language('build/my-languages.so', 'go')

parser = Parser()
parser.set_language(GO_LANGUAGE)

# %% [markdown]
# ### Define the commit for each year
#
# See track_ft_changes_kops.ipynb for the methodology on how to find these commits

# %%
years = [str(year) for year in range(2017, 2022)]
coms = ["c72ef959b710612855fe4a03460d2bbd9d38fd7d",
        "94ef2027bed84f7335b5f3aa37f3fec99eb04089",
        "2c204246567cebcb5badf11550cc2778aa9b79a9",
        "5db135e3bd4e66e1c5e9301914fc7c33eed7f4a7",
        "6b538c395c9acaa3a472a634dad1ff651e3a375d"]

commits = dict()

for i in range(len(years)):
    commits[years[i]] = coms[i]
    
cmd_line = "cd ~/Documents/vamos2022/kops && git reset --hard "

# %% [markdown]
# ### Search for keywords

# %%
def get_keywords():
    exp = "[N|n]ew.*,*Bool*"

    with open("./kops/pkg/featureflag/featureflag.go", 'r') as f:
        catch_feat = re.findall(exp, f.read())

    keywords = [feature.split('"')[1] for feature in catch_feat]

    # removing "Azure" because it affects more than 100 files, probably a bug 
    if "Azure" in keywords:
        keywords.remove("Azure")

    return keywords

get_keywords()
# Out:
# ['CacheNodeidentityInfo',
#  'DNSPreCreate',
#  'EnableLaunchTemplates',
#  'EnableExternalCloudController',
#  'EnableExternalDNS',
#  'EnableSeparateConfigBase',
#  'ExperimentalClusterDNS',
#  'GoogleCloudBucketAcl',
#  'KeepLaunchConfigurations',
#  'SkipTerraformFormat',
#  'SpecOverrideFlag',
#  'Spotinst',
#  'SpotinstOcean',
#  'SpotinstHybrid',
#  'SpotinstController',
#  'VFSVaultSupport',
#  'VPCSkipEnableDNSSupport',
#  'SkipEtcdVersionCheck',
#  'TerraformJSON',
#  'LegacyIAM',
#  'ClusterAddons',
#  'UseServiceAccountIAM',
#  'PublicJWKS']

# %% [markdown]
# ### Analyse the FT interferences

# %%
for year in years:
    
    print("\n------------\nSTART ANALYSING FOR YEAR", year,"\n------------\n")
    
    os.system(cmd_line+commits[year])
    keywords = get_keywords()
    
    print("\n--\nKeywords\n--\n")
    print(keywords)
    
    print("\n--\nFiles\n--\n")

    go_folders = [x[0] for x in os.walk("./kops/")]

    go_files = []
    for dir_name in go_folders:
        files = [dir_name+"/"+k for k in os.listdir(dir_name) if k[len(k)-3:] ==".go"]
        go_files.extend(files)

    go_file_interests = []

    for file in go_files:
        s = ""
        with open(file, "r") as f:
            s+=f.read()+"\n"
        kw_file = [k for k in keywords if k in s]
        if len(kw_file) > 0 and "featureflag" in s:
            print(file, "contains :")
            for kw in kw_file:
                print("->",kw)
            go_file_interests.append(file)
            print("\n")


    print("\n--\nAnalyse FT\n--\n")

    for gfi in go_file_interests:

        s = ""
        with open(gfi, "r") as f:
            s+=f.read()+"\n"

        print("File :            ", gfi, "\n")

        source = bytes(s, "utf8")
        ast = parser.parse(source)

        root_node = ast.root_node

        tree = Tree()

        root_node = ast.root_node

        type_nodes = dict()

        def get_name(node):
            return source[node.start_byte:node.end_byte].decode('utf8')

        def get_id(node):
            global type_nodes
            node_type = node.type
            if node_type not in type_nodes:
                type_nodes[node_type]=1
            else:
                type_nodes[node_type]+=1
            return node_type+str(type_nodes[node_type])

        def process(root_id, node):
            global tree
            node_id = get_id(node)
            node_name = get_name(node)
            for kw in keywords:
                if kw in node_name and node.type == 'if_statement':
                    #print("\n\n"+get_name(node)+"\n\n")
                    for c in node.children:
                        if c.type == 'binary_expression' or c.type == 'unary_expression' or c.type == 'call_expression':
                            print("->",get_name(c))
            tree.create_node(node_name,
                             node_id,
                             parent = root_id)
            if len(node.children) != 0:
                for i in range(len(node.children)):
                    process(node_id, node.children[i])

        tree.create_node("root", "root")
        for i in range(len(root_node.children)):
            process("root", root_node.children[i])
        print("\n")

        #tree.show()
# Out:
# ------------
# START ANALYSING FOR YEAR 2017
# ------------
#
#
# --
# Keywords
# --
#
# ['DNSPreCreate']
#
# --
# Files
# --
#
# ./kops/upup/pkg/fi/cloudup/dns.go contains :
# -> DNSPreCreate
#
#
# ./kops/pkg/featureflag/featureflag.go contains :
# -> DNSPreCreate
#
#
#
# --
# Analyse FT
# --
#
# File :             ./kops/upup/pkg/fi/cloudup/dns.go
#
# -> !featureflag.DNSPreCreate.Enabled()
#
#
# File :             ./kops/pkg/featureflag/featureflag.go
#
#
#
#
# ------------
# START ANALYSING FOR YEAR 2018
# ------------
#
#
# --
# Keywords
# --
#
# ['DNSPreCreate', 'DrainAndValidateRollingUpdate', 'VPCSkipEnableDNSSupport', 'SkipTerraformFormat', 'VSphereCloudProvider', 'EnableExternalDNS', 'EnableExternalCloudController', 'EnableSeparateConfigBase', 'SpecOverrideFlag']
#
# --
# Files
# --
#
# ./kops/upup/pkg/fi/cloudup/dns.go contains :
# -> DNSPreCreate
#
#
# ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder.go contains :
# -> EnableExternalDNS
# -> EnableExternalCloudController
#
#
# ./kops/upup/pkg/fi/cloudup/terraform/hcl_printer.go contains :
# -> SkipTerraformFormat
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go contains :
# -> VPCSkipEnableDNSSupport
#
#
# ./kops/pkg/instancegroups/instancegroups.go contains :
# -> DrainAndValidateRollingUpdate
#
#
# ./kops/pkg/featureflag/featureflag.go contains :
# -> DNSPreCreate
# -> DrainAndValidateRollingUpdate
# -> VPCSkipEnableDNSSupport
# -> SkipTerraformFormat
# -> VSphereCloudProvider
# -> EnableExternalDNS
# -> EnableExternalCloudController
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
#
#
# ./kops/cmd/kops/rollingupdatecluster.go contains :
# -> DrainAndValidateRollingUpdate
#
#
# ./kops/cmd/kops/create_cluster.go contains :
# -> VSphereCloudProvider
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
#
#
#
# --
# Analyse FT
# --
#
# File :             ./kops/upup/pkg/fi/cloudup/dns.go
#
# -> !featureflag.DNSPreCreate.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder.go
#
# -> featureflag.EnableExternalDNS.Enabled()
# -> featureflag.EnableExternalCloudController.Enabled() && b.cluster.Spec.ExternalCloudControllerManager != nil
#
#
# File :             ./kops/upup/pkg/fi/cloudup/terraform/hcl_printer.go
#
# -> featureflag.SkipTerraformFormat.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go
#
# -> changes != nil && changes.EnableDNSSupport != nil
# -> featureflag.VPCSkipEnableDNSSupport.Enabled()
#
#
# File :             ./kops/pkg/instancegroups/instancegroups.go
#
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
#
#
# File :             ./kops/pkg/featureflag/featureflag.go
#
#
#
# File :             ./kops/cmd/kops/rollingupdatecluster.go
#
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
#
#
# File :             ./kops/cmd/kops/create_cluster.go
#
# -> featureflag.EnableSeparateConfigBase.Enabled()
# -> featureflag.SpecOverrideFlag.Enabled()
# -> featureflag.VSphereCloudProvider.Enabled()
# -> c.Cloud != ""
# -> c.Cloud == "vsphere"
# -> !featureflag.VSphereCloudProvider.Enabled()
#
#
#
# ------------
# START ANALYSING FOR YEAR 2019
# ------------
#
#
# --
# Keywords
# --
#
# ['ExperimentalClusterDNS', 'KeepLaunchConfigurations', 'DNSPreCreate', 'DrainAndValidateRollingUpdate', 'VPCSkipEnableDNSSupport', 'SkipTerraformFormat', 'VSphereCloudProvider', 'EnableExternalDNS', 'EnableExternalCloudController', 'EnableSeparateConfigBase', 'SpecOverrideFlag', 'GoogleCloudBucketAcl', 'EnableNodeAuthorization', 'Spotinst']
#
# --
# Files
# --
#
# ./kops/upup/pkg/fi/cloudup/template_functions.go contains :
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/apply_cluster.go contains :
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/dns.go contains :
# -> DNSPreCreate
#
#
# ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder.go contains :
# -> EnableExternalDNS
# -> EnableExternalCloudController
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/terraform/hcl_printer.go contains :
# -> SkipTerraformFormat
#
#
# ./kops/upup/pkg/fi/cloudup/awsup/aws_cloud.go contains :
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go contains :
# -> VPCSkipEnableDNSSupport
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/launchconfiguration.go contains :
# -> KeepLaunchConfigurations
#
#
# ./kops/pkg/model/bastion.go contains :
# -> Spotinst
#
#
# ./kops/pkg/model/gcemodel/storageacl.go contains :
# -> GoogleCloudBucketAcl
#
#
# ./kops/pkg/model/awsmodel/api_loadbalancer.go contains :
# -> Spotinst
#
#
# ./kops/pkg/instancegroups/instancegroups.go contains :
# -> DrainAndValidateRollingUpdate
#
#
# ./kops/pkg/resources/aws/aws.go contains :
# -> Spotinst
#
#
# ./kops/pkg/apis/kops/validation/legacy.go contains :
# -> ExperimentalClusterDNS
# -> EnableNodeAuthorization
#
#
# ./kops/pkg/commands/set_cluster.go contains :
# -> SpecOverrideFlag
#
#
# ./kops/pkg/featureflag/featureflag.go contains :
# -> ExperimentalClusterDNS
# -> KeepLaunchConfigurations
# -> DNSPreCreate
# -> DrainAndValidateRollingUpdate
# -> VPCSkipEnableDNSSupport
# -> SkipTerraformFormat
# -> VSphereCloudProvider
# -> EnableExternalDNS
# -> EnableExternalCloudController
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
# -> GoogleCloudBucketAcl
# -> EnableNodeAuthorization
# -> Spotinst
#
#
# ./kops/cmd/kops/rollingupdatecluster.go contains :
# -> DrainAndValidateRollingUpdate
#
#
# ./kops/cmd/kops/create_cluster.go contains :
# -> VSphereCloudProvider
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
# -> Spotinst
#
#
#
# --
# Analyse FT
# --
#
# File :             ./kops/upup/pkg/fi/cloudup/template_functions.go
#
# -> featureflag.Spotinst.Enabled()
# -> err == nil
#
#
# File :             ./kops/upup/pkg/fi/cloudup/apply_cluster.go
#
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/dns.go
#
# -> !featureflag.DNSPreCreate.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder.go
#
# -> featureflag.EnableExternalDNS.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> featureflag.EnableExternalCloudController.Enabled() && b.cluster.Spec.ExternalCloudControllerManager != nil
#
#
# File :             ./kops/upup/pkg/fi/cloudup/terraform/hcl_printer.go
#
# -> featureflag.SkipTerraformFormat.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awsup/aws_cloud.go
#
# -> raw == nil
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go
#
# -> changes != nil && changes.EnableDNSSupport != nil
# -> featureflag.VPCSkipEnableDNSSupport.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/launchconfiguration.go
#
# -> featureflag.KeepLaunchConfigurations.Enabled()
#
#
# File :             ./kops/pkg/model/bastion.go
#
# -> !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/model/gcemodel/storageacl.go
#
# -> featureflag.GoogleCloudBucketAcl.Enabled()
#
#
# File :             ./kops/pkg/model/awsmodel/api_loadbalancer.go
#
# -> !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/instancegroups/instancegroups.go
#
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
#
#
# File :             ./kops/pkg/resources/aws/aws.go
#
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/apis/kops/validation/legacy.go
#
# -> c.Spec.KubeDNS != nil
# -> c.Spec.KubeDNS.ServerIP != ""
# -> !featureflag.ExperimentalClusterDNS.Enabled()
# -> c.Spec.NodeAuthorization != nil
# -> !featureflag.EnableNodeAuthorization.Enabled()
#
#
# File :             ./kops/pkg/commands/set_cluster.go
#
# -> !featureflag.SpecOverrideFlag.Enabled()
#
#
# File :             ./kops/pkg/featureflag/featureflag.go
#
#
#
# File :             ./kops/cmd/kops/rollingupdatecluster.go
#
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
#
#
# File :             ./kops/cmd/kops/create_cluster.go
#
# -> featureflag.EnableSeparateConfigBase.Enabled()
# -> featureflag.SpecOverrideFlag.Enabled()
# -> featureflag.VSphereCloudProvider.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> c.Cloud != ""
# -> c.Cloud != ""
# -> c.Cloud == "vsphere"
# -> !featureflag.VSphereCloudProvider.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> c.SpotinstProduct != ""
# -> c.SpotinstOrientation != ""
#
#
#
# ------------
# START ANALYSING FOR YEAR 2020
# ------------
#
#
# --
# Keywords
# --
#
# ['DNSPreCreate', 'DrainAndValidateRollingUpdate', 'EnableLaunchTemplates', 'EnableExternalCloudController', 'EnableExternalDNS', 'EnableNodeAuthorization', 'EnableSeparateConfigBase', 'ExperimentalClusterDNS', 'GoogleCloudBucketAcl', 'KeepLaunchConfigurations', 'SkipTerraformFormat', 'SpecOverrideFlag', 'Spotinst', 'SpotinstOcean', 'VPCSkipEnableDNSSupport', 'VSphereCloudProvider', 'SkipEtcdVersionCheck']
#
# --
# Files
# --
#
# ./kops/upup/pkg/fi/cloudup/template_functions.go contains :
# -> EnableExternalCloudController
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/apply_cluster.go contains :
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/dns.go contains :
# -> DNSPreCreate
#
#
# ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder.go contains :
# -> EnableExternalCloudController
# -> EnableExternalDNS
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/template_functions_test.go contains :
# -> EnableExternalCloudController
#
#
# ./kops/upup/pkg/fi/cloudup/terraform/hcl_printer.go contains :
# -> SkipTerraformFormat
#
#
# ./kops/upup/pkg/fi/cloudup/awsup/aws_cloud.go contains :
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go contains :
# -> VPCSkipEnableDNSSupport
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/launchconfiguration.go contains :
# -> KeepLaunchConfigurations
#
#
# ./kops/pkg/model/bastion.go contains :
# -> Spotinst
#
#
# ./kops/pkg/model/awsmodel/context.go contains :
# -> EnableLaunchTemplates
#
#
# ./kops/pkg/model/awsmodel/api_loadbalancer.go contains :
# -> Spotinst
#
#
# ./kops/pkg/model/components/etcdmanager/options.go contains :
# -> SkipEtcdVersionCheck
#
#
# ./kops/pkg/model/spotinstmodel/instance_group.go contains :
# -> Spotinst
# -> SpotinstOcean
#
#
# ./kops/pkg/instancegroups/instancegroups.go contains :
# -> DrainAndValidateRollingUpdate
#
#
# ./kops/pkg/resources/aws/aws.go contains :
# -> Spotinst
#
#
# ./kops/pkg/apis/kops/validation/legacy.go contains :
# -> EnableNodeAuthorization
# -> ExperimentalClusterDNS
#
#
# ./kops/pkg/commands/set_cluster.go contains :
# -> SpecOverrideFlag
#
#
# ./kops/pkg/featureflag/featureflag.go contains :
# -> DNSPreCreate
# -> DrainAndValidateRollingUpdate
# -> EnableLaunchTemplates
# -> EnableExternalCloudController
# -> EnableExternalDNS
# -> EnableNodeAuthorization
# -> EnableSeparateConfigBase
# -> ExperimentalClusterDNS
# -> GoogleCloudBucketAcl
# -> KeepLaunchConfigurations
# -> SkipTerraformFormat
# -> SpecOverrideFlag
# -> Spotinst
# -> SpotinstOcean
# -> VPCSkipEnableDNSSupport
# -> VSphereCloudProvider
# -> SkipEtcdVersionCheck
# ./kops/cmd/kops/rollingupdatecluster.go contains :
# -> DrainAndValidateRollingUpdate
#
#
# ./kops/cmd/kops/create_cluster.go contains :
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
# -> Spotinst
# -> VSphereCloudProvider
#
#
#
# --
# Analyse FT
# --
#
# File :             ./kops/upup/pkg/fi/cloudup/template_functions.go
#
# -> featureflag.EnableExternalCloudController.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> err == nil
#
#
# File :             ./kops/upup/pkg/fi/cloudup/apply_cluster.go
#
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/dns.go
#
# -> !featureflag.DNSPreCreate.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder.go
#
# -> featureflag.EnableExternalDNS.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> featureflag.EnableExternalCloudController.Enabled() && b.cluster.Spec.ExternalCloudControllerManager != nil
#
#
# File :             ./kops/upup/pkg/fi/cloudup/template_functions_test.go
#
#
#
# File :             ./kops/upup/pkg/fi/cloudup/terraform/hcl_printer.go
#
# -> featureflag.SkipTerraformFormat.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awsup/aws_cloud.go
#
# -> raw == nil
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go
#
# -> changes != nil && changes.EnableDNSSupport != nil
# -> featureflag.VPCSkipEnableDNSSupport.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/launchconfiguration.go
#
# -> featureflag.KeepLaunchConfigurations.Enabled()
#
#
# File :             ./kops/pkg/model/bastion.go
#
# -> !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/model/awsmodel/context.go
#
# -> featureflag.EnableLaunchTemplates.Enabled()
#
#
# File :             ./kops/pkg/model/awsmodel/api_loadbalancer.go
#
# -> !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/model/components/etcdmanager/options.go
#
# -> !etcdVersionIsSupported(etcdCluster.Version)
# -> featureflag.SkipEtcdVersionCheck.Enabled()
#
#
# File :             ./kops/pkg/model/spotinstmodel/instance_group.go
#
# -> featureflag.SpotinstOcean.Enabled()
# -> featureflag.SpotinstOcean.Enabled()
# -> cfg != nil
#
#
# File :             ./kops/pkg/instancegroups/instancegroups.go
#
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
#
#
# File :             ./kops/pkg/resources/aws/aws.go
#
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/apis/kops/validation/legacy.go
#
# -> c.Spec.KubeDNS != nil
# -> c.Spec.KubeDNS.ServerIP != ""
# -> !featureflag.ExperimentalClusterDNS.Enabled()
# -> c.Spec.NodeAuthorization != nil
# -> !featureflag.EnableNodeAuthorization.Enabled()
#
#
# File :             ./kops/pkg/commands/set_cluster.go
#
# -> !featureflag.SpecOverrideFlag.Enabled()
#
#
# File :             ./kops/pkg/featureflag/featureflag.go
#
#
#
# File :             ./kops/cmd/kops/rollingupdatecluster.go
#
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
# -> featureflag.DrainAndValidateRollingUpdate.Enabled()
#
#
# File :             ./kops/cmd/kops/create_cluster.go
#
# -> featureflag.EnableSeparateConfigBase.Enabled()
# -> featureflag.SpecOverrideFlag.Enabled()
# -> featureflag.VSphereCloudProvider.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> c.Cloud != ""
# -> c.Cloud != ""
# -> c.Cloud == "vsphere"
# -> !featureflag.VSphereCloudProvider.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> c.SpotinstProduct != ""
# -> c.SpotinstOrientation != ""
#
#
#
# ------------
# START ANALYSING FOR YEAR 2021
# ------------
#
#
# --
# Keywords
# --
#
# ['CacheNodeidentityInfo', 'DNSPreCreate', 'EnableLaunchTemplates', 'EnableExternalCloudController', 'EnableExternalDNS', 'EnableSeparateConfigBase', 'ExperimentalClusterDNS', 'GoogleCloudBucketAcl', 'KeepLaunchConfigurations', 'SkipTerraformFormat', 'SpecOverrideFlag', 'Spotinst', 'SpotinstOcean', 'SpotinstHybrid', 'SpotinstController', 'VFSVaultSupport', 'VPCSkipEnableDNSSupport', 'SkipEtcdVersionCheck', 'TerraformJSON', 'LegacyIAM', 'ClusterAddons', 'UseServiceAccountIAM', 'PublicJWKS']
#
# --
# Files
# --
#
# ./kops/upup/pkg/fi/cloudup/template_functions.go contains :
# -> CacheNodeidentityInfo
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder_test.go contains :
# -> EnableExternalCloudController
# -> UseServiceAccountIAM
# -> PublicJWKS
#
#
# ./kops/upup/pkg/fi/cloudup/apply_cluster.go contains :
# -> Spotinst
# -> SpotinstHybrid
#
#
# ./kops/upup/pkg/fi/cloudup/dns.go contains :
# -> DNSPreCreate
#
#
# ./kops/upup/pkg/fi/cloudup/new_cluster.go contains :
# -> Spotinst
#
#
# ./kops/upup/pkg/fi/cloudup/alitasks/launchconfiguration.go contains :
# -> KeepLaunchConfigurations
#
#
# ./kops/upup/pkg/fi/cloudup/terraform/target.go contains :
# -> TerraformJSON
#
#
# ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder/bootstrapchannelbuilder.go contains :
# -> EnableExternalDNS
# -> Spotinst
# -> SpotinstController
# -> ClusterAddons
# -> UseServiceAccountIAM
# -> PublicJWKS
#
#
# ./kops/upup/pkg/fi/cloudup/awsup/aws_cloud.go contains :
# -> Spotinst
# -> SpotinstHybrid
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go contains :
# -> VPCSkipEnableDNSSupport
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/launchtemplate_target_terraform.go contains :
# -> TerraformJSON
#
#
# ./kops/upup/pkg/fi/cloudup/awstasks/launchconfiguration.go contains :
# -> KeepLaunchConfigurations
#
#
# ./kops/pkg/model/context.go contains :
# -> UseServiceAccountIAM
#
#
# ./kops/pkg/model/awsmodel/oidc_provider.go contains :
# -> PublicJWKS
#
#
# ./kops/pkg/model/awsmodel/context.go contains :
# -> EnableLaunchTemplates
#
#
# ./kops/pkg/model/awsmodel/autoscalinggroup.go contains :
# -> Spotinst
# -> SpotinstHybrid
#
#
# ./kops/pkg/model/components/apiserver.go contains :
# -> PublicJWKS
#
#
# ./kops/pkg/model/components/discovery.go contains :
# -> PublicJWKS
#
#
# ./kops/pkg/model/components/etcdmanager/options.go contains :
# -> SkipEtcdVersionCheck
#
#
# ./kops/pkg/model/spotinstmodel/instance_group.go contains :
# -> Spotinst
# -> SpotinstOcean
# -> SpotinstHybrid
#
#
# ./kops/pkg/instancegroups/settings.go contains :
# -> Spotinst
#
#
# ./kops/pkg/resources/aws/aws.go contains :
# -> Spotinst
#
#
# ./kops/pkg/apis/kops/validation/legacy.go contains :
# -> ExperimentalClusterDNS
# -> VFSVaultSupport
#
#
# ./kops/pkg/apis/kops/validation/validation.go contains :
# -> EnableExternalCloudController
# -> Spotinst
# -> LegacyIAM
# -> UseServiceAccountIAM
#
#
# ./kops/pkg/commands/set_cluster.go contains :
# -> SpecOverrideFlag
#
#
# ./kops/pkg/featureflag/featureflag.go contains :
# -> CacheNodeidentityInfo
# -> DNSPreCreate
# -> EnableLaunchTemplates
# -> EnableExternalCloudController
# -> EnableExternalDNS
# -> EnableSeparateConfigBase
# -> ExperimentalClusterDNS
# -> GoogleCloudBucketAcl
# -> KeepLaunchConfigurations
# -> SkipTerraformFormat
# -> SpecOverrideFlag
# -> Spotinst
# -> SpotinstOcean
# -> SpotinstHybrid
# -> SpotinstController
# -> VFSVaultSupport
# -> VPCSkipEnableDNSSupport
# -> SkipEtcdVersionCheck
# -> TerraformJSON
# -> LegacyIAM
# -> ClusterAddons
# -> UseServiceAccountIAM
# -> PublicJWKS
#
#
# ./kops/cmd/kops/integration_test.go contains :
# -> EnableLaunchTemplates
# -> TerraformJSON
# -> UseServiceAccountIAM
# -> PublicJWKS
#
#
# ./kops/cmd/kops/create_cluster.go contains :
# -> EnableSeparateConfigBase
# -> SpecOverrideFlag
# -> Spotinst
# -> ClusterAddons
#
#
#
# --
# Analyse FT
# --
#
# File :             ./kops/upup/pkg/fi/cloudup/template_functions.go
#
# -> featureflag.Spotinst.Enabled()
# -> err == nil
# -> featureflag.CacheNodeidentityInfo.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder_test.go
#
#
#
# File :             ./kops/upup/pkg/fi/cloudup/apply_cluster.go
#
# -> featureflag.Spotinst.Enabled()
# -> featureflag.Spotinst.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/dns.go
#
# -> !featureflag.DNSPreCreate.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/new_cluster.go
#
# -> featureflag.Spotinst.Enabled()
# -> opt.SpotinstProduct != ""
# -> opt.SpotinstOrientation != ""
#
#
# File :             ./kops/upup/pkg/fi/cloudup/alitasks/launchconfiguration.go
#
# -> featureflag.KeepLaunchConfigurations.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/terraform/target.go
#
# -> featureflag.TerraformJSON.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/bootstrapchannelbuilder/bootstrapchannelbuilder.go
#
# -> b.ClusterAddons != nil
# -> featureflag.PublicJWKS.Enabled()
# -> externalDNS == nil || !externalDNS.Disable
# -> b.UseServiceAccountIAM()
# -> featureflag.EnableExternalDNS.Enabled()
# -> featureflag.Spotinst.Enabled() && featureflag.SpotinstController.Enabled()
# -> featureflag.Spotinst.Enabled() && featureflag.SpotinstController.Enabled()
# File :             ./kops/upup/pkg/fi/cloudup/awsup/aws_cloud.go
#
# -> raw == nil
# -> featureflag.Spotinst.Enabled()
# -> c.spotinst != nil
# -> c.spotinst != nil
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> c.spotinst != nil
# -> c.spotinst != nil
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> c.spotinst != nil
# -> c.spotinst != nil
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/vpc.go
#
# -> changes != nil && changes.EnableDNSSupport != nil
# -> featureflag.VPCSkipEnableDNSSupport.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/launchtemplate_target_terraform.go
#
# -> e.UserData != nil
# -> d != nil
# -> featureflag.TerraformJSON.Enabled()
#
#
# File :             ./kops/upup/pkg/fi/cloudup/awstasks/launchconfiguration.go
#
# -> featureflag.KeepLaunchConfigurations.Enabled()
#
#
# File :             ./kops/pkg/model/context.go
#
#
#
# File :             ./kops/pkg/model/awsmodel/oidc_provider.go
#
# -> featureflag.PublicJWKS.Enabled()
#
#
# File :             ./kops/pkg/model/awsmodel/context.go
#
# -> featureflag.EnableLaunchTemplates.Enabled()
#
#
# File :             ./kops/pkg/model/awsmodel/autoscalinggroup.go
#
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/model/components/apiserver.go
#
# -> featureflag.PublicJWKS.Enabled()
#
#
# File :             ./kops/pkg/model/components/discovery.go
#
#
#
# File :             ./kops/pkg/model/components/etcdmanager/options.go
#
# -> !etcdVersionIsSupported(etcdCluster.Version)
# -> featureflag.SkipEtcdVersionCheck.Enabled()
#
#
# File :             ./kops/pkg/model/spotinstmodel/instance_group.go
#
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstHybrid.Enabled()
# -> featureflag.SpotinstOcean.Enabled()
# -> featureflag.SpotinstOcean.Enabled()
# -> cfg != nil
# -> !featureflag.SpotinstOcean.Enabled()
# -> !featureflag.SpotinstOcean.Enabled()
#
#
# File :             ./kops/pkg/instancegroups/settings.go
#
# -> rollingUpdate.MaxSurge == nil
# -> kops.CloudProviderID(cluster.Spec.CloudProvider) == kops.CloudProviderAWS && !featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/resources/aws/aws.go
#
# -> featureflag.Spotinst.Enabled()
#
#
# File :             ./kops/pkg/apis/kops/validation/legacy.go
#
# -> c.Spec.KubeDNS != nil
# -> c.Spec.KubeDNS.ServerIP != ""
# -> ip == nil
# -> !featureflag.ExperimentalClusterDNS.Enabled()
# -> isExperimentalClusterDNS(c.Spec.Kubelet, c.Spec.KubeDNS)
# -> isExperimentalClusterDNS(c.Spec.MasterKubelet, c.Spec.KubeDNS)
# -> strings.HasPrefix(c.Spec.SecretStore, "vault://")
# -> !featureflag.VFSVaultSupport.Enabled()
# -> strings.HasPrefix(c.Spec.KeyStore, "vault://")
# -> !featureflag.VFSVaultSupport.Enabled()
#
#
# File :             ./kops/pkg/apis/kops/validation/validation.go
#
# -> spec.ExternalCloudControllerManager != nil
# -> kops.CloudProviderID(spec.CloudProvider) != kops.CloudProviderOpenstack && !featureflag.EnableExternalCloudController.Enabled()
# -> (spec.IAM == nil || spec.IAM.Legacy) && !featureflag.LegacyIAM.Enabled()
# -> (spec.IAM == nil || spec.IAM.Legacy) && featureflag.UseServiceAccountIAM.Enabled()
# -> spec.API != nil && spec.API.LoadBalancer != nil && spec.CloudProvider == "aws"
# -> featureflag.Spotinst.Enabled() && spec.API.LoadBalancer.Class == kops.LoadBalancerClassNetwork
#
#
# File :             ./kops/pkg/commands/set_cluster.go
#
# -> !featureflag.SpecOverrideFlag.Enabled()
#
#
# File :             ./kops/pkg/featureflag/featureflag.go
#
#
#
# File :             ./kops/cmd/kops/integration_test.go
#
# -> featureflag.EnableLaunchTemplates.Enabled()
#
#
# File :             ./kops/cmd/kops/create_cluster.go
#
# -> featureflag.EnableSeparateConfigBase.Enabled()
# -> featureflag.ClusterAddons.Enabled()
# -> featureflag.SpecOverrideFlag.Enabled()
# -> featureflag.Spotinst.Enabled()
