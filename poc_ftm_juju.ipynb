# %% [markdown]
# ### Install some libs

# %% [markdown]
# !pip install treelib

# %% [markdown]
# !pip3 install tree_sitter

# %% [markdown]
# ### Import some libs

# %%
from treelib import Node, Tree
from tree_sitter import Language, Parser
import os
import numpy as np

# %% [markdown]
# ### Initialize Tree-sitter go parser

# %%
Language.build_library(
  # Store the library in the `build` directory
  'build/my-languages.so',

  # Include one or more languages
  [
    'tree-sitter-go'
  ]
)

GO_LANGUAGE = Language('build/my-languages.so', 'go')

parser = Parser()
parser.set_language(GO_LANGUAGE)

# %% [markdown]
# ## Step I : Find the Feature Toggles (FT)

# %% [markdown]
# ### I-1. Find the names of FT
#
# Here, we are cheating, since all the features flags are in the flags.go file
#
# But we have to think on how to automate this step!
#
# Given a software with feature flags, how to extract the feature flags, their names, their expiration date, and so on...

# %%
s = ""
with open("./juju-develop/feature/flags.go", "r") as f:
    s+=f.read()+"\n"
print(s)
# Out:
# // Copyright 2015 Canonical Ltd.
# // Licensed under the AGPLv3, see LICENCE file for details.
#
# // Package feature package defines the names of the current feature flags.
# package feature
#
# // TODO (anastasiamac 2015-03-02)
# // Features that have commands that can be blocked,
# // command list for "juju block" and "juju unblock"
# // needs to be maintained until we can dynamically discover
# // these commands.
#
# // LogErrorStack is a developer feature flag to have the LoggedErrorStack
# // function in the utils package write out the error stack as defined by the
# // errors package to the logger.  The ability to log the error stack is very
# // useful in those error cases where you really don't expect there to be a
# // failure.  This means that the developers with this flag set will see the
# // stack trace in the log output, but normal deployments never will.
# const LogErrorStack = "log-error-stack"
#
# // LegacyUpstart is used to indicate that the version-based init system
# // discovery code (service.VersionInitSystem) should return upstart
# // instead of systemd for vivid and newer.
# const LegacyUpstart = "legacy-upstart"
#
# // DeveloperMode allows access to developer specific commands and behaviour.
# const DeveloperMode = "developer-mode"
#
# // StrictMigration will cause migration to error if there are unexported
# // values for annotations, status, status history, or settings.
# const StrictMigration = "strict-migration"
#
# // Branches will allow for model branches functionality to be used.
# const Branches = "branches"
#
# // Generations will allow for model generation functionality to be used.
# // This is a deprecated flag name and is synonymous with "branches" above.
# const Generations = "generations"
#
# // RawK8sSpec indicates that it's allowed to set k8s spec using raw yaml format.
# const RawK8sSpec = "raw-k8s-spec"
#
# // ActionsV2 enables the next generation actions UX.
# const ActionsV2 = "actions-v2"
#
# // Secrets enables the secrets feature.
# const Secrets = "secrets"
#
# // AsynchronousCharmDownloads enables support for asynchronous charm downloads.
# const AsynchronousCharmDownloads = "async-charm-downloads"
#
# // RaftBatchFSM will use the batching FSM instead of the singular FSM to attempt
# // to commit logs.
# const RaftBatchFSM = "raft-batch-fsm"
#
# // RaftAPILeases will switch all lease store management transport, currently
# // handled by Pubsub to facade API interaction.
# const RaftAPILeases = "raft-api-leases"
#
# // CharmAssumes instructs Juju to process assumes expressions from charm
# // metadata when attempting to deploy charms. In addition, it enables reporting
# // of supported features as part of the 'juju show-model' output.
# const CharmAssumes = "charm-assumes"

# %%
source = bytes(s, "utf8")
ast = parser.parse(source)

root_node = ast.root_node

print(root_node.type)
print(root_node.start_point)
print(root_node.end_point)
print(root_node.children[1])
# Out:
# source_file
# (0, 0)
# (64, 0)
# <Node kind=comment, start_point=(1, 0), end_point=(1, 59)>

# %% [markdown]
# #### List all keywords

# %%
for i in range(len(root_node.children)):
    current_node = root_node.children[i]
    for j in range(len(current_node.children)):
        print(source[current_node.start_byte:current_node.end_byte].decode('utf8'))
        #print(current_node)#.child_by_field_name('const_declaration'))
        #if current_node.children[j].type == "const_spec":
        #    if current_node.children[j].is_named:
        #        print(current_node.children[j].)
# Out:
# package feature
# package feature
# const LogErrorStack = "log-error-stack"
# const LogErrorStack = "log-error-stack"
# const LegacyUpstart = "legacy-upstart"
# const LegacyUpstart = "legacy-upstart"
# const DeveloperMode = "developer-mode"
# const DeveloperMode = "developer-mode"
# const StrictMigration = "strict-migration"
# const StrictMigration = "strict-migration"
# const Branches = "branches"
# const Branches = "branches"
# const Generations = "generations"
# const Generations = "generations"
# const RawK8sSpec = "raw-k8s-spec"
# const RawK8sSpec = "raw-k8s-spec"
# const ActionsV2 = "actions-v2"
# const ActionsV2 = "actions-v2"
# const Secrets = "secrets"
# const Secrets = "secrets"
# const AsynchronousCharmDownloads = "async-charm-downloads"
# const AsynchronousCharmDownloads = "async-charm-downloads"
# const RaftBatchFSM = "raft-batch-fsm"
# const RaftBatchFSM = "raft-batch-fsm"
# const RaftAPILeases = "raft-api-leases"
# const RaftAPILeases = "raft-api-leases"
# const CharmAssumes = "charm-assumes"
# const CharmAssumes = "charm-assumes"

# %% [markdown]
# ### Step I-1. results : juju keywords!!!

# %%
keywords = ["LogErrorStack", "LegacyUpstart", "DeveloperMode", "StrictMigration",
            "Branches", "Generations", "RawK8sSpec", "ActionsV2", "Secrets",
            "AsynchronousCharmDownloads", "RaftBatchFSM", "RaftAPILeases", "CharmAssumes"]

# %% [markdown]
# ### I-2. List files with keywords

# %% [markdown]
# #### List all .go files

# %%
go_folders = [x[0] for x in os.walk("./juju-develop/")]

go_files = []
for dir_name in go_folders:
    files = [dir_name+"/"+k for k in os.listdir(dir_name) if k[len(k)-3:] ==".go"]
    go_files.extend(files)

print("10 random .go files in this project :")
for k in range(10):
    print(go_files[np.random.randint(len(go_files))])
# Out:
# 10 random .go files in this project :
# ./juju-develop/api/common/charm/charmorigin.go
# ./juju-develop/api/controller/controller_test.go
# ./juju-develop/api/instancemutater/instancemutater_test.go
# ./juju-develop/core/status/status_history.go
# ./juju-develop/provider/azure/internal/azureauth/package_test.go
# ./juju-develop/cmd/juju/model/defaults.go
# ./juju-develop/api/backups/create.go
# ./juju-develop/state/backups/export_test.go
# ./juju-develop/apiserver/facades/agent/retrystrategy/retrystrategy_test.go
# ./juju-develop/api/bundle/client_test.go

# %%
len(go_files)
# Out:
# 5873

# %% [markdown]
# #### List the interesting files, containing at least one keyword with the featureflag

# %%
go_file_interests = []

for file in go_files:
    s = ""
    with open(file, "r") as f:
        s+=f.read()+"\n"
    kw_file = [k for k in keywords if k in s]
    if len(kw_file) > 0 and "featureflag" in s:
        print(file, "contains :")
        for kw in kw_file:
            print("->",kw)
        go_file_interests.append(file)
        print("\n")
# Out:
# ./juju-develop/apiserver/embeddedcli.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/apiserver/logstream.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/apiserver/pubsub.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/apiserver/logsink/logsink.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/provider/manual/environ.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/state/migration_export.go contains :
# -> StrictMigration
#
#
# ./juju-develop/state/database.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/jujuclient/models.go contains :
# -> Branches
# -> Generations
#
#
# ./juju-develop/caas/kubernetes/provider/operator.go contains :
# -> Secrets
#
#
# ./juju-develop/caas/kubernetes/provider/bootstrap.go contains :
# -> Secrets
#
#
# ./juju-develop/caas/kubernetes/provider/application/application.go contains :
# -> Secrets
#
#
# ./juju-develop/environs/bootstrap/prepare.go contains :
# -> Branches
# -> Generations
#
#
# ./juju-develop/service/discovery.go contains :
# -> LegacyUpstart
#
#
# ./juju-develop/service/discovery_test.go contains :
# -> LegacyUpstart
#
#
# ./juju-develop/worker/provisioner/logging.go contains :
# -> LogErrorStack
#
#
# ./juju-develop/worker/uniter/runner/jujuc/server.go contains :
# -> Secrets
#
#
# ./juju-develop/api/state.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/cmd/juju/controller/addmodel.go contains :
# -> Branches
# -> Generations
#
#
# ./juju-develop/cmd/juju/application/config.go contains :
# -> Branches
# -> Generations
#
#
# ./juju-develop/cmd/juju/commands/bootstrap.go contains :
# -> Branches
# -> Generations
#
#
# ./juju-develop/cmd/juju/commands/main_test.go contains :
# -> ActionsV2
# -> Secrets
#
#
# ./juju-develop/cmd/juju/commands/upgradecontroller.go contains :
# -> DeveloperMode
#
#
# ./juju-develop/cmd/juju/commands/main.go contains :
# -> DeveloperMode
# -> Branches
# -> Generations
# -> Secrets

# %%
len(go_file_interests)
# Out:
# 23

# %% [markdown]
# ## Step 2 : extract AST

# %% [markdown]
# #### The use of py-tree-sitter to extract the AST

# %%
s = ""
with open("./juju-develop/feature/flags.go", "r") as f:
    s+=f.read()+"\n"

source = bytes(s, "utf8")
ast = parser.parse(source)

root_node = ast.root_node

tree = Tree()

root_node = ast.root_node

type_nodes = dict()

source = bytes(s, "utf8")
ast = parser.parse(source)

root_node = ast.root_node

def get_name(node):
    return source[node.start_byte:node.end_byte].decode('utf8')

def get_id(node):
    global type_nodes
    node_type = node.type
    if node_type not in type_nodes:
        type_nodes[node_type]=1
    else:
        type_nodes[node_type]+=1
    return node_type+str(type_nodes[node_type])

def process(root_id, node):
    global tree
    node_id = get_id(node)
    node_name = get_name(node)
    tree.create_node(node_name,
                     node_id,
                     parent = root_id)
    if len(node.children) != 0:
        for i in range(len(node.children)):
            process(node_id, node.children[i])

tree.create_node("root", "root")
for i in range(len(root_node.children)):
    process("root", root_node.children[i])

tree.show()
# Out:
# root
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├──
#
#
# ├── // ActionsV2 enables the next generation actions UX.
# ├── // AsynchronousCharmDownloads enables support for asynchronous charm downloads.
# ├── // Branches will allow for model branches functionality to be used.
# ├── // CharmAssumes instructs Juju to process assumes expressions from charm
# ├── // Copyright 2015 Canonical Ltd.
# ├── // DeveloperMode allows access to developer specific commands and behaviour.
# ├── // Features that have commands that can be blocked,
# ├── // Generations will allow for model generation functionality to be used.
# ├── // LegacyUpstart is used to indicate that the version-based init system
# ├── // Licensed under the AGPLv3, see LICENCE file for details.
# ├── // LogErrorStack is a developer feature flag to have the LoggedErrorStack
# ├── // Package feature package defines the names of the current feature flags.
# ├── // RaftAPILeases will switch all lease store management transport, currently
# ├── // RaftBatchFSM will use the batching FSM instead of the singular FSM to attempt
# ├── // RawK8sSpec indicates that it's allowed to set k8s spec using raw yaml format.
# ├── // Secrets enables the secrets feature.
# ├── // StrictMigration will cause migration to error if there are unexported
# ├── // TODO (anastasiamac 2015-03-02)
# ├── // This is a deprecated flag name and is synonymous with "branches" above.
# ├── // command list for "juju block" and "juju unblock"
# ├── // discovery code (service.VersionInitSystem) should return upstart
# ├── // errors package to the logger.  The ability to log the error stack is very
# ├── // failure.  This means that the developers with this flag set will see the
# ├── // function in the utils package write out the error stack as defined by the
# ├── // handled by Pubsub to facade API interaction.
# ├── // instead of systemd for vivid and newer.
# ├── // metadata when attempting to deploy charms. In addition, it enables reporting
# ├── // needs to be maintained until we can dynamically discover
# ├── // of supported features as part of the 'juju show-model' output.
# ├── // stack trace in the log output, but normal deployments never will.
# ├── // these commands.
# ├── // to commit logs.
# ├── // useful in those error cases where you really don't expect there to be a
# ├── // values for annotations, status, status history, or settings.
# ├── const ActionsV2 = "actions-v2"
# │   ├── ActionsV2 = "actions-v2"
# │   │   ├── "actions-v2"
# │   │   │   └── "actions-v2"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── ActionsV2
# │   └── const
# ├── const AsynchronousCharmDownloads = "async-charm-downloads"
# │   ├── AsynchronousCharmDownloads = "async-charm-downloads"
# │   │   ├── "async-charm-downloads"
# │   │   │   └── "async-charm-downloads"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── AsynchronousCharmDownloads
# │   └── const
# ├── const Branches = "branches"
# │   ├── Branches = "branches"
# │   │   ├── "branches"
# │   │   │   └── "branches"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── Branches
# │   └── const
# ├── const CharmAssumes = "charm-assumes"
# │   ├── CharmAssumes = "charm-assumes"
# │   │   ├── "charm-assumes"
# │   │   │   └── "charm-assumes"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── CharmAssumes
# │   └── const
# ├── const DeveloperMode = "developer-mode"
# │   ├── DeveloperMode = "developer-mode"
# │   │   ├── "developer-mode"
# │   │   │   └── "developer-mode"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── DeveloperMode
# │   └── const
# ├── const Generations = "generations"
# │   ├── Generations = "generations"
# │   │   ├── "generations"
# │   │   │   └── "generations"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── Generations
# │   └── const
# ├── const LegacyUpstart = "legacy-upstart"
# │   ├── LegacyUpstart = "legacy-upstart"
# │   │   ├── "legacy-upstart"
# │   │   │   └── "legacy-upstart"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── LegacyUpstart
# │   └── const
# ├── const LogErrorStack = "log-error-stack"
# │   ├── LogErrorStack = "log-error-stack"
# │   │   ├── "log-error-stack"
# │   │   │   └── "log-error-stack"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── LogErrorStack
# │   └── const
# ├── const RaftAPILeases = "raft-api-leases"
# │   ├── RaftAPILeases = "raft-api-leases"
# │   │   ├── "raft-api-leases"
# │   │   │   └── "raft-api-leases"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── RaftAPILeases
# │   └── const
# ├── const RaftBatchFSM = "raft-batch-fsm"
# │   ├── RaftBatchFSM = "raft-batch-fsm"
# │   │   ├── "raft-batch-fsm"
# │   │   │   └── "raft-batch-fsm"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── RaftBatchFSM
# │   └── const
# ├── const RawK8sSpec = "raw-k8s-spec"
# │   ├── RawK8sSpec = "raw-k8s-spec"
# │   │   ├── "raw-k8s-spec"
# │   │   │   └── "raw-k8s-spec"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── RawK8sSpec
# │   └── const
# ├── const Secrets = "secrets"
# │   ├── Secrets = "secrets"
# │   │   ├── "secrets"
# │   │   │   └── "secrets"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── Secrets
# │   └── const
# ├── const StrictMigration = "strict-migration"
# │   ├── StrictMigration = "strict-migration"
# │   │   ├── "strict-migration"
# │   │   │   └── "strict-migration"
# │   │   │       ├── "
# │   │   │       └── "
# │   │   ├── =
# │   │   └── StrictMigration
# │   └── const
# └── package feature
#     ├── feature
#     └── package

# %% [markdown]
# ## Step 3 - Search Feature Toggles dependencies in the AST

# %%
for gfi in go_file_interests:
    
    s = ""
    with open(gfi, "r") as f:
        s+=f.read()+"\n"

    print("File :            ", gfi, "\n")

    source = bytes(s, "utf8")
    ast = parser.parse(source)

    root_node = ast.root_node

    tree = Tree()

    root_node = ast.root_node

    type_nodes = dict()

    def get_name(node):
        return source[node.start_byte:node.end_byte].decode('utf8')

    def get_id(node):
        global type_nodes
        node_type = node.type
        if node_type not in type_nodes:
            type_nodes[node_type]=1
        else:
            type_nodes[node_type]+=1
        return node_type+str(type_nodes[node_type])

    def process(root_id, node):
        global tree
        node_id = get_id(node)
        node_name = get_name(node)
        for kw in keywords:
            if kw in node_name and node.type == 'if_statement':
                for c in node.children:
                    if c.type == 'binary_expression' or c.type == 'call_expression':
                        print("->",get_name(c))
        tree.create_node(node_name,
                         node_id,
                         parent = root_id)
        if len(node.children) != 0:
            for i in range(len(node.children)):
                process(node_id, node.children[i])

    tree.create_node("root", "root")
    for i in range(len(root_node.children)):
        process("root", root_node.children[i])
    print("\n")

    #tree.show()
# Out:
# File :             ./juju-develop/apiserver/embeddedcli.go
#
# -> cmdErr != nil && featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/apiserver/logstream.go
#
# -> err != nil && featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/apiserver/pubsub.go
#
# -> err != nil && featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/apiserver/logsink/logsink.go
#
# -> err != nil && featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/provider/manual/environ.go
#
# -> featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/state/migration_export.go
#
# -> featureflag.Enabled(feature.StrictMigration)
#
#
# File :             ./juju-develop/state/database.go
#
# -> featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/jujuclient/models.go
#
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
#
#
# File :             ./juju-develop/caas/kubernetes/provider/operator.go
#
# -> operatorImageDetails.IsPrivate()
#
#
# File :             ./juju-develop/caas/kubernetes/provider/bootstrap.go
#
#
#
# File :             ./juju-develop/caas/kubernetes/provider/application/application.go
#
# -> v.Image.Password != ""
#
#
# File :             ./juju-develop/environs/bootstrap/prepare.go
#
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
#
#
# File :             ./juju-develop/service/discovery.go
#
# -> featureflag.Enabled(feature.LegacyUpstart)
#
#
# File :             ./juju-develop/service/discovery_test.go
#
# -> featureflag.Enabled(feature.LegacyUpstart)
#
#
# File :             ./juju-develop/worker/provisioner/logging.go
#
# -> featureflag.Enabled(feature.LogErrorStack)
#
#
# File :             ./juju-develop/worker/uniter/runner/jujuc/server.go
#
# -> featureflag.Enabled(feature.Secrets)
#
#
# File :             ./juju-develop/api/state.go
#
# -> featureflag.Enabled(feature.DeveloperMode)
#
#
# File :             ./juju-develop/cmd/juju/controller/addmodel.go
#
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
#
#
# File :             ./juju-develop/cmd/juju/application/config.go
#
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> !featureflag.Enabled(feature.Branches) && !featureflag.Enabled(feature.Generations) && c.branchName == ""
# -> !featureflag.Enabled(feature.Branches) && !featureflag.Enabled(feature.Generations) && c.branchName == ""
# -> (featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)) && err == nil
# -> (featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)) && err == nil
#
#
# File :             ./juju-develop/cmd/juju/commands/bootstrap.go
#
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
#
#
# File :             ./juju-develop/cmd/juju/commands/main_test.go
#
#
#
# File :             ./juju-develop/cmd/juju/commands/upgradecontroller.go
#
# -> !featureflag.Enabled(feature.DeveloperMode) && streamsVersions.Size() > 0
#
#
# File :             ./juju-develop/cmd/juju/commands/main.go
#
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.Branches) || featureflag.Enabled(feature.Generations)
# -> featureflag.Enabled(feature.DeveloperMode)
# -> featureflag.Enabled(feature.Secrets)

# %%
type_nodes
# Out:
# {'comment': 69,
#  'package_clause': 1,
#  'package': 1,
#  'package_identifier': 36,
#  '\n': 357,
#  'import_declaration': 1,
#  'import': 1,
#  'import_spec_list': 1,
#  '(': 465,
#  'import_spec': 44,
#  'interpreted_string_literal': 61,
#  '"': 122,
#  ')': 465,
#  'var_declaration': 8,
#  'var': 8,
#  'var_spec': 8,
#  'identifier': 628,
#  '=': 14,
#  'expression_list': 98,
#  'call_expression': 421,
#  'selector_expression': 419,
#  '.': 451,
#  'field_identifier': 458,
#  'argument_list': 421,
#  'function_declaration': 7,
#  'func': 20,
#  'parameter_list': 39,
#  'block': 48,
#  '{': 66,
#  ',': 86,
#  '}': 66,
#  'raw_string_literal': 4,
#  'slice_expression': 6,
#  '[': 21,
#  'int_literal': 22,
#  ':': 24,
#  ']': 21,
#  'const_declaration': 2,
#  'const': 2,
#  'const_spec': 2,
#  'type_conversion_expression': 1,
#  'slice_type': 8,
#  'type_identifier': 99,
#  'escape_sequence': 26,
#  'parameter_declaration': 50,
#  'return_statement': 28,
#  'return': 28,
#  'composite_literal': 11,
#  'literal_value': 11,
#  'keyed_element': 18,
#  'type_declaration': 7,
#  'type': 7,
#  'type_spec': 7,
#  'struct_type': 4,
#  'struct': 4,
#  'field_declaration_list': 4,
#  'field_declaration': 9,
#  'function_type': 1,
#  'variadic_parameter_declaration': 2,
#  '...': 5,
#  'pointer_type': 9,
#  '*': 9,
#  'qualified_type': 30,
#  'method_declaration': 8,
#  'short_var_declaration': 22,
#  ':=': 26,
#  'if_statement': 24,
#  'if': 24,
#  'binary_expression': 25,
#  '!=': 9,
#  'nil': 22,
#  'unary_expression': 10,
#  '!': 3,
#  'assignment_statement': 8,
#  ';': 8,
#  'true': 1,
#  'for_statement': 4,
#  'for': 4,
#  'range_clause': 4,
#  'range': 4,
#  'index_expression': 4,
#  '^=': 1,
#  '==': 7,
#  'variadic_argument': 3,
#  '>': 2,
#  '&&': 4,
#  '||': 2,
#  '-': 1,
#  'false': 1,
#  'func_literal': 4,
#  '&': 7,
#  'interface_type': 3,
#  'interface': 3,
#  'method_spec_list': 3,
#  'method_spec': 5,
#  'type_assertion_expression': 2,
#  'else': 1,
#  'map_type': 3,
#  'map': 3}

# %%
# Pattern matching -> does not work yet

# %% [markdown]
# query = GO_LANGUAGE.query("""
# (function_definition
#   name: (identifier) @function.def)
#
# (call
#   function: (identifier) @function.call)
# """)
#
# captures = query.captures(tree.root_node)
