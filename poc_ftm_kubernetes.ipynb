# %% [markdown]
# ### Install some libs

# %% [markdown]
# !pip install treelib

# %% [markdown]
# !pip3 install tree_sitter

# %% [markdown]
# ### Import some libs

# %%
from treelib import Node, Tree
from tree_sitter import Language, Parser
import os
import numpy as np

# %% [markdown]
# ### Initialize Tree-sitter go parser

# %%
Language.build_library(
  # Store the library in the `build` directory
  'build/my-languages.so',

  # Include one or more languages
  [
    'tree-sitter-go'
  ]
)

GO_LANGUAGE = Language('build/my-languages.so', 'go')

parser = Parser()
parser.set_language(GO_LANGUAGE)

# %% [markdown]
# ## Step I : Find the Feature Toggles (FT)

# %% [markdown]
# ```
# $ egrep -R "=" kubernetes/pkg/features/kube_features.go | grep -v "//"
# py> keys = [k.split('=')[0].split(' ')[0] for k in feats.replace('\t', '').split('\n')]
# ```

# %%
keywords = ['AppArmor',
 'DynamicKubeletConfig',
 'ExperimentalHostUserNamespaceDefaultingGate',
 'DevicePlugins',
 'HPAScaleToZero',
 'RotateKubeletServerCertificate',
 'LocalStorageCapacityIsolation',
 'ExpandPersistentVolumes',
 'ExpandInUsePersistentVolumes',
 'ExpandCSIVolumes',
 'EphemeralContainers',
 'QOSReserved',
 'CPUManager',
 'CPUCFSQuotaPeriod',
 'TopologyManager',
 'MemoryManager',
 'StorageObjectInUseProtection',
 'VolumeSubpath',
 'CSIInlineVolume',
 'CSIStorageCapacity',
 'DefaultPodTopologySpread',
 'GenericEphemeralVolume',
 'PreferNominatedNode',
 'RuntimeClass',
 'NetworkPolicyEndPort',
 'ProcMountType',
 'TTLAfterFinished',
 'IndexedJob',
 'JobTrackingWithFinalizers',
 'JobReadyPods',
 'KubeletPodResources',
 'CSIMigration',
 'CSIMigrationGCE',
 'InTreePluginGCEUnregister',
 'CSIMigrationAWS',
 'InTreePluginAWSUnregister',
 'CSIMigrationAzureDisk',
 'InTreePluginAzureDiskUnregister',
 'CSIMigrationAzureFile',
 'InTreePluginAzureFileUnregister',
 'CSIMigrationvSphere',
 'InTreePluginvSphereUnregister',
 'CSIMigrationOpenStack',
 'InTreePluginOpenStackUnregister',
 'CSIVolumeFSGroupPolicy',
 'ConfigurableFSGroupPolicy',
 'DelegateFSGroupToCSIDriver',
 'LocalStorageCapacityIsolationFSQuotaMonitoring',
 'NonPreemptingPriority',
 'PodOverhead',
 'IPv6DualStack',
 'EndpointSlice',
 'EndpointSliceProxying',
 'WindowsEndpointSliceProxying',
 'PodDisruptionBudget',
 'DaemonSetUpdateSurge',
 'ImmutableEphemeralVolumes',
 'HugePageStorageMediumSize',
 'DownwardAPIHugePages',
 'AnyVolumeDataSource',
 'SetHostnameAsFQDN',
 'WinOverlay',
 'WinDSR',
 'DisableAcceleratorUsageMetrics',
 'HPAContainerMetrics',
 'EndpointSliceTerminatingCondition',
 'ProxyTerminatingEndpoints',
 'EndpointSliceNodeName',
 'SizeMemoryBackedVolumes',
 'ExecProbeTimeout',
 'KubeletCredentialProviders',
 'DisableCloudProviders',
 'DisableKubeletCloudCredentialProviders',
 'CSIServiceAccountToken',
 'GracefulNodeShutdown',
 'ServiceLBNodePortControl',
 'MixedProtocolLBService',
 'VolumeCapacityPriority',
 'PodDeletionCost',
 'TopologyAwareHints',
 'ProbeTerminationGracePeriod',
 'NodeSwap',
 'PodAffinityNamespaceSelector',
 'ServiceLoadBalancerClass',
 'LogarithmicScaleDown',
 'IngressClassNamespacedParams',
 'ServiceInternalTrafficPolicy',
 'SuspendJob',
 'KubeletPodResourcesGetAllocatable',
 'NamespaceDefaultLabelName',
 'CSIVolumeHealth',
 'WindowsHostProcessContainers',
 'StatefulSetMinReadySeconds',
 'IdentifyPodOS',
 'ExpandedDNSConfig',
 'SeccompDefault',
 'PodSecurity',
 'ReadWriteOncePod',
 'CSRDuration',
 'KubeletInUserNamespace',
 'MemoryQoS',
 'CPUManagerPolicyOptions',
 'ControllerManagerLeaderMigration',
 'CPUManagerPolicyAlphaOptions',
 'CPUManagerPolicyBetaOptions',
 'JobMutableNodeSchedulingDirectives']

# %% [markdown]
# ### List files with keywords

# %% [markdown]
# #### List all .go files

# %%
go_folders = [x[0] for x in os.walk("./kubernetes/")]

go_files = []
for dir_name in go_folders:
    files = [dir_name+"/"+k for k in os.listdir(dir_name) if k[len(k)-3:] ==".go"] # if k.endswith(".go")
    go_files.extend(files)

print("10 random .go files in this project :")
for k in range(10):
    print(go_files[np.random.randint(len(go_files))])
# Out:
# 10 random .go files in this project :
# ./kubernetes/pkg/volume/awsebs/aws_ebs_test.go
# ./kubernetes/pkg/registry/core/podtemplate/strategy_test.go
# ./kubernetes/vendor/golang.org/x/sys/unix/ztypes_solaris_amd64.go
# ./kubernetes/staging/src/k8s.io/client-go/kubernetes/typed/apps/v1beta2/controllerrevision.go
# ./kubernetes/staging/src/k8s.io/apimachinery/pkg/util/rand/rand.go
# ./kubernetes/vendor/go.etcd.io/etcd/server/v3/etcdserver/api/v2http/httptypes/errors.go
# ./kubernetes/vendor/github.com/godbus/dbus/v5/default_handler.go
# ./kubernetes/staging/src/k8s.io/client-go/informers/internalinterfaces/factory_interfaces.go
# ./kubernetes/staging/src/k8s.io/client-go/applyconfigurations/core/v1/windowssecuritycontextoptions.go
# ./kubernetes/vendor/golang.org/x/net/http2/ascii.go

# %%
len(go_files)
# Out:
# 15182

# %% [markdown]
# # List the interesting files, containing at least one keyword with the featureflag

# %%
go_file_interests = []

for file in go_files:
    s = ""
    with open(file, "r") as f:
        s+=f.read()+"\n"
    kw_file = [k for k in keywords if k in s]
    if len(kw_file) > 0 and "featuregate" in s:
        print(file, "contains :")
        for kw in kw_file:
            print("->",kw)
        go_file_interests.append(file)
        print("\n")
# Out:
# ./kubernetes/plugin/pkg/admission/priority/admission_test.go contains :
# -> NonPreemptingPriority
#
#
# ./kubernetes/plugin/pkg/admission/priority/admission.go contains :
# -> NonPreemptingPriority
#
#
# ./kubernetes/plugin/pkg/admission/noderestriction/admission.go contains :
# -> ExpandPersistentVolumes
#
#
# ./kubernetes/plugin/pkg/admission/runtimeclass/admission_test.go contains :
# -> RuntimeClass
# -> PodOverhead
#
#
# ./kubernetes/plugin/pkg/admission/runtimeclass/admission.go contains :
# -> RuntimeClass
# -> PodOverhead
#
#
# ./kubernetes/plugin/pkg/admission/resourcequota/admission_test.go contains :
# -> ExpandPersistentVolumes
#
#
# ./kubernetes/plugin/pkg/admission/security/podsecurity/admission_test.go contains :
# -> PodSecurity
#
#
# ./kubernetes/plugin/pkg/admission/security/podsecurity/admission.go contains :
# -> PodSecurity
#
#
# ./kubernetes/plugin/pkg/admission/security/podsecuritypolicy/admission_test.go contains :
# -> AppArmor
# -> CSIInlineVolume
# -> PodSecurity
#
#
# ./kubernetes/plugin/pkg/auth/authorizer/node/node_authorizer.go contains :
# -> ExpandPersistentVolumes
#
#
# ./kubernetes/staging/src/k8s.io/controller-manager/pkg/leadermigration/options/options_test.go contains :
# -> ControllerManagerLeaderMigration
#
#
# ./kubernetes/staging/src/k8s.io/controller-manager/pkg/features/kube_features.go contains :
# -> IPv6DualStack
# -> ControllerManagerLeaderMigration
#
#
# ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures.go contains :
# -> PodSecurity
#
#
# ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures_appArmorProfile.go contains :
# -> AppArmor
#
#
# ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures_procMount.go contains :
# -> ProcMountType
#
#
# ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures_windowsHostProcess.go contains :
# -> WindowsHostProcessContainers
#
#
# ./kubernetes/staging/src/k8s.io/pod-security-admission/test/run.go contains :
# -> RuntimeClass
# -> PodSecurity
#
#
# ./kubernetes/staging/src/k8s.io/legacy-cloud-providers/azure/azure_standard.go contains :
# -> IPv6DualStack
#
#
# ./kubernetes/staging/src/k8s.io/legacy-cloud-providers/azure/azure.go contains :
# -> IPv6DualStack
#
#
# ./kubernetes/test/e2e/framework/util.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/test/e2e/framework/skipper/skipper.go contains :
# -> AppArmor
#
#
# ./kubernetes/test/integration/dryrun/dryrun_test.go contains :
# -> StorageObjectInUseProtection
#
#
# ./kubernetes/test/integration/scheduler/predicates_test.go contains :
# -> PodAffinityNamespaceSelector
#
#
# ./kubernetes/test/integration/scheduler/preemption_test.go contains :
# -> PreferNominatedNode
# -> NonPreemptingPriority
# -> PodDisruptionBudget
#
#
# ./kubernetes/test/integration/scheduler/priorities_test.go contains :
# -> DefaultPodTopologySpread
# -> PodAffinityNamespaceSelector
#
#
# ./kubernetes/test/integration/quota/quota_test.go contains :
# -> ServiceLBNodePortControl
#
#
# ./kubernetes/test/integration/endpointslice/endpointsliceterminating_test.go contains :
# -> EndpointSlice
# -> EndpointSliceTerminatingCondition
#
#
# ./kubernetes/test/integration/pods/pods_test.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/test/integration/service/loadbalancer_test.go contains :
# -> ServiceLBNodePortControl
# -> ServiceLoadBalancerClass
#
#
# ./kubernetes/test/integration/auth/node_test.go contains :
# -> DynamicKubeletConfig
# -> ExpandPersistentVolumes
#
#
# ./kubernetes/test/integration/auth/podsecurity_test.go contains :
# -> AppArmor
# -> RuntimeClass
# -> ProcMountType
# -> WindowsHostProcessContainers
# -> PodSecurity
#
#
# ./kubernetes/test/integration/scheduler_perf/scheduler_perf_legacy_test.go contains :
# -> CSIMigration
# -> CSIMigrationAWS
#
#
# ./kubernetes/test/integration/replicationcontroller/replicationcontroller_test.go contains :
# -> LogarithmicScaleDown
#
#
# ./kubernetes/test/integration/volumescheduling/volume_binding_test.go contains :
# -> CSIStorageCapacity
#
#
# ./kubernetes/test/integration/volumescheduling/volume_capacity_priority_test.go contains :
# -> VolumeCapacityPriority
#
#
# ./kubernetes/test/integration/replicaset/replicaset_test.go contains :
# -> PodDeletionCost
#
#
# ./kubernetes/test/integration/statefulset/statefulset_test.go contains :
# -> StatefulSetMinReadySeconds
#
#
# ./kubernetes/test/integration/apiserver/apiserver_test.go contains :
# -> EndpointSlice
#
#
# ./kubernetes/test/integration/apiserver/print_test.go contains :
# -> EphemeralContainers
# -> CSIStorageCapacity
#
#
# ./kubernetes/test/integration/job/job_test.go contains :
# -> IndexedJob
# -> JobTrackingWithFinalizers
# -> JobReadyPods
# -> SuspendJob
# -> JobMutableNodeSchedulingDirectives
#
#
# ./kubernetes/test/e2e_node/util.go contains :
# -> DynamicKubeletConfig
#
#
# ./kubernetes/pkg/apis/scheduling/v1/defaults_test.go contains :
# -> NonPreemptingPriority
#
#
# ./kubernetes/pkg/apis/scheduling/v1beta1/defaults_test.go contains :
# -> NonPreemptingPriority
#
#
# ./kubernetes/pkg/apis/scheduling/v1alpha1/defaults_test.go contains :
# -> NonPreemptingPriority
#
#
# ./kubernetes/pkg/apis/scheduling/util/util_test.go contains :
# -> NonPreemptingPriority
#
#
# ./kubernetes/pkg/apis/core/v1/defaults_test.go contains :
# -> EphemeralContainers
# -> ServiceInternalTrafficPolicy
#
#
# ./kubernetes/pkg/apis/core/pods/helpers_test.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/pkg/apis/core/validation/conditional_validation_test.go contains :
# -> MixedProtocolLBService
#
#
# ./kubernetes/pkg/apis/core/validation/validation_test.go contains :
# -> AppArmor
# -> LocalStorageCapacityIsolation
# -> ExpandPersistentVolumes
# -> EphemeralContainers
# -> RuntimeClass
# -> DownwardAPIHugePages
# -> SetHostnameAsFQDN
# -> PodDeletionCost
# -> ProbeTerminationGracePeriod
# -> PodAffinityNamespaceSelector
# -> ServiceInternalTrafficPolicy
# -> WindowsHostProcessContainers
# -> IdentifyPodOS
# -> ExpandedDNSConfig
# -> PodSecurity
# -> ReadWriteOncePod
#
#
# ./kubernetes/pkg/apis/storage/v1/defaults_test.go contains :
# -> CSIInlineVolume
# -> CSIStorageCapacity
#
#
# ./kubernetes/pkg/apis/storage/v1beta1/defaults_test.go contains :
# -> CSIInlineVolume
# -> CSIStorageCapacity
#
#
# ./kubernetes/pkg/apis/storage/validation/validation_test.go contains :
# -> CSIStorageCapacity
# -> CSIMigration
# -> CSIServiceAccountToken
#
#
# ./kubernetes/pkg/apis/storage/util/util_test.go contains :
# -> ExpandPersistentVolumes
#
#
# ./kubernetes/pkg/apis/apps/validation/validation_test.go contains :
# -> EphemeralContainers
# -> DaemonSetUpdateSurge
# -> StatefulSetMinReadySeconds
#
#
# ./kubernetes/pkg/apis/autoscaling/validation/validation_test.go contains :
# -> HPAScaleToZero
#
#
# ./kubernetes/pkg/apis/batch/v1/defaults_test.go contains :
# -> IndexedJob
# -> SuspendJob
#
#
# ./kubernetes/pkg/apis/networking/v1/defaults_test.go contains :
# -> IngressClassNamespacedParams
#
#
# ./kubernetes/pkg/apis/networking/validation/validation_test.go contains :
# -> IngressClassNamespacedParams
#
#
# ./kubernetes/pkg/scheduler/generic_scheduler_test.go contains :
# -> PreferNominatedNode
#
#
# ./kubernetes/pkg/scheduler/apis/config/v1beta2/defaults_test.go contains :
# -> DefaultPodTopologySpread
# -> VolumeCapacityPriority
#
#
# ./kubernetes/pkg/scheduler/apis/config/v1beta2/default_plugins_test.go contains :
# -> DefaultPodTopologySpread
#
#
# ./kubernetes/pkg/scheduler/apis/config/validation/validation_pluginargs_test.go contains :
# -> VolumeCapacityPriority
#
#
# ./kubernetes/pkg/scheduler/apis/config/v1beta3/defaults_test.go contains :
# -> DefaultPodTopologySpread
# -> VolumeCapacityPriority
#
#
# ./kubernetes/pkg/scheduler/apis/config/v1beta3/default_plugins_test.go contains :
# -> DefaultPodTopologySpread
#
#
# ./kubernetes/pkg/scheduler/framework/plugins/volumerestrictions/volume_restrictions_test.go contains :
# -> ReadWriteOncePod
#
#
# ./kubernetes/pkg/scheduler/framework/plugins/nodevolumelimits/csi_test.go contains :
# -> CSIMigration
# -> CSIMigrationAWS
#
#
# ./kubernetes/pkg/scheduler/framework/plugins/noderesources/fit_test.go contains :
# -> LocalStorageCapacityIsolation
# -> PodOverhead
#
#
# ./kubernetes/pkg/scheduler/framework/plugins/volumebinding/binder_test.go contains :
# -> CSIStorageCapacity
# -> GenericEphemeralVolume
# -> CSIMigration
# -> CSIMigrationGCE
#
#
# ./kubernetes/pkg/quota/v1/evaluator/core/pods_test.go contains :
# -> PodOverhead
# -> PodAffinityNamespaceSelector
#
#
# ./kubernetes/pkg/quota/v1/evaluator/core/services_test.go contains :
# -> ServiceLBNodePortControl
#
#
# ./kubernetes/pkg/volume/volume_linux_test.go contains :
# -> ConfigurableFSGroupPolicy
# ./kubernetes/pkg/volume/csi/csi_mounter_test.go contains :
# -> CSIInlineVolume
# -> CSIVolumeFSGroupPolicy
# -> DelegateFSGroupToCSIDriver
#
#
# ./kubernetes/pkg/volume/csi/csi_plugin_test.go contains :
# -> CSIInlineVolume
# -> CSIVolumeFSGroupPolicy
#
#
# ./kubernetes/pkg/volume/csi/csi_attacher_test.go contains :
# -> CSIInlineVolume
# -> DelegateFSGroupToCSIDriver
#
#
# ./kubernetes/pkg/volume/csi/csi_client_test.go contains :
# -> CSIVolumeHealth
# -> ReadWriteOncePod
#
#
# ./kubernetes/pkg/volume/csi/csi_test.go contains :
# -> CSIInlineVolume
#
#
# ./kubernetes/pkg/volume/csimigration/plugin_manager.go contains :
# -> CSIMigration
# -> CSIMigrationGCE
# -> InTreePluginGCEUnregister
# -> CSIMigrationAWS
# -> InTreePluginAWSUnregister
# -> CSIMigrationAzureDisk
# -> InTreePluginAzureDiskUnregister
# -> CSIMigrationAzureFile
# -> InTreePluginAzureFileUnregister
# -> CSIMigrationvSphere
# -> InTreePluginvSphereUnregister
# -> CSIMigrationOpenStack
# -> InTreePluginOpenStackUnregister
#
#
# ./kubernetes/pkg/volume/csimigration/plugin_manager_test.go contains :
# -> CSIMigration
# -> CSIMigrationGCE
# -> InTreePluginGCEUnregister
# -> CSIMigrationAWS
# -> InTreePluginAWSUnregister
# -> CSIMigrationvSphere
# -> InTreePluginvSphereUnregister
#
#
# ./kubernetes/pkg/volume/emptydir/empty_dir_test.go contains :
# -> SizeMemoryBackedVolumes
#
#
# ./kubernetes/pkg/volume/util/util_test.go contains :
# -> EphemeralContainers
# -> PodSecurity
#
#
# ./kubernetes/pkg/volume/util/fsquota/quota_linux_test.go contains :
# -> LocalStorageCapacityIsolation
# -> LocalStorageCapacityIsolationFSQuotaMonitoring
#
#
# ./kubernetes/pkg/kubelet/apis/podresources/server_v1_test.go contains :
# -> KubeletPodResources
# -> KubeletPodResourcesGetAllocatable
#
#
# ./kubernetes/pkg/kubelet/container/helpers_test.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/pkg/kubelet/server/stats/volume_stat_calculator_test.go contains :
# -> CSIVolumeHealth
#
#
# ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_manager_test.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_sandbox_test.go contains :
# -> RuntimeClass
# -> WindowsHostProcessContainers
# -> PodSecurity
#
#
# ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_container_test.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_container_linux_test.go contains :
# -> EphemeralContainers
# -> NodeSwap
# -> MemoryQoS
#
#
# ./kubernetes/pkg/kubelet/kuberuntime/helpers_linux_test.go contains :
# -> CPUCFSQuotaPeriod
#
#
# ./kubernetes/pkg/kubelet/network/dns/dns_test.go contains :
# -> ExpandedDNSConfig
#
#
# ./kubernetes/pkg/kubelet/dockershim/exec_test.go contains :
# -> ExecProbeTimeout
#
#
# ./kubernetes/pkg/kubelet/volumemanager/reconciler/reconciler_test.go contains :
# -> ExpandInUsePersistentVolumes
#
#
# ./kubernetes/pkg/kubelet/volumemanager/populator/desired_state_of_world_populator_test.go contains :
# -> ExpandInUsePersistentVolumes
#
#
# ./kubernetes/pkg/kubelet/eviction/eviction_manager_test.go contains :
# -> LocalStorageCapacityIsolation
#
#
# ./kubernetes/pkg/kubelet/eviction/helpers_test.go contains :
# -> LocalStorageCapacityIsolation
#
#
# ./kubernetes/pkg/kubelet/nodeshutdown/nodeshutdown_manager_linux_test.go contains :
# -> GracefulNodeShutdown
#
#
# ./kubernetes/pkg/kubelet/cm/helpers_linux_test.go contains :
# -> CPUCFSQuotaPeriod
# -> MemoryQoS
#
#
# ./kubernetes/pkg/kubelet/cm/cpumanager/policy_options_test.go contains :
# -> CPUManager
# -> CPUManagerPolicyBetaOptions
#
#
# ./kubernetes/pkg/registry/certificates/certificates/strategy_test.go contains :
# -> CSRDuration
#
#
# ./kubernetes/pkg/registry/certificates/certificates/storage/metrics_test.go contains :
# -> CSRDuration
#
#
# ./kubernetes/pkg/registry/core/pod/strategy_test.go contains :
# -> EphemeralContainers
# -> PodSecurity
#
#
# ./kubernetes/pkg/registry/core/namespace/strategy_test.go contains :
# -> NamespaceDefaultLabelName
#
#
# ./kubernetes/pkg/registry/core/service/strategy_test.go contains :
# -> MixedProtocolLBService
# -> ServiceLoadBalancerClass
# -> ServiceInternalTrafficPolicy
#
#
# ./kubernetes/pkg/registry/core/service/storage/storage_test.go contains :
# -> ServiceLBNodePortControl
# -> MixedProtocolLBService
# -> ServiceInternalTrafficPolicy
#
#
# ./kubernetes/pkg/registry/core/persistentvolumeclaim/strategy_test.go contains :
# -> ExpandPersistentVolumes
# -> AnyVolumeDataSource
#
#
# ./kubernetes/pkg/registry/core/persistentvolumeclaim/storage/storage_test.go contains :
# -> AnyVolumeDataSource
#
#
# ./kubernetes/pkg/registry/core/resourcequota/strategy_test.go contains :
# -> PodAffinityNamespaceSelector
#
#
# ./kubernetes/pkg/registry/core/node/strategy_test.go contains :
# -> DynamicKubeletConfig
#
#
# ./kubernetes/pkg/registry/storage/csidriver/strategy_test.go contains :
# -> CSIInlineVolume
# -> CSIStorageCapacity
#
#
# ./kubernetes/pkg/registry/storage/csistoragecapacity/strategy_test.go contains :
# -> CSIStorageCapacity
#
#
# ./kubernetes/pkg/registry/storage/volumeattachment/strategy_test.go contains :
# -> CSIMigration
#
#
# ./kubernetes/pkg/registry/apps/daemonset/strategy_test.go contains :
# -> DaemonSetUpdateSurge
#
#
# ./kubernetes/pkg/registry/apps/statefulset/strategy_test.go contains :
# -> StatefulSetMinReadySeconds
#
#
# ./kubernetes/pkg/registry/autoscaling/horizontalpodautoscaler/strategy_test.go contains :
# -> HPAContainerMetrics
#
#
# ./kubernetes/pkg/registry/discovery/endpointslice/strategy_test.go contains :
# -> EndpointSlice
# -> EndpointSliceTerminatingCondition
# -> TopologyAwareHints
#
#
# ./kubernetes/pkg/registry/batch/job/strategy_test.go contains :
# -> IndexedJob
# -> JobTrackingWithFinalizers
# -> SuspendJob
# -> JobMutableNodeSchedulingDirectives
#
#
# ./kubernetes/pkg/registry/networking/networkpolicy/strategy_test.go contains :
# -> NetworkPolicyEndPort
#
#
# ./kubernetes/pkg/registry/networking/ingressclass/strategy_test.go contains :
# -> IngressClassNamespacedParams
#
#
# ./kubernetes/pkg/features/kube_features.go contains :
# -> AppArmor
# -> DynamicKubeletConfig
# -> ExperimentalHostUserNamespaceDefaultingGate
# -> DevicePlugins
# -> HPAScaleToZero
# -> RotateKubeletServerCertificate
# -> LocalStorageCapacityIsolation
# -> ExpandPersistentVolumes
# -> ExpandInUsePersistentVolumes
# -> ExpandCSIVolumes
# -> EphemeralContainers
# -> QOSReserved
# -> CPUManager
# -> CPUCFSQuotaPeriod
# -> TopologyManager
# -> MemoryManager
# -> StorageObjectInUseProtection
# -> VolumeSubpath
# -> CSIInlineVolume
# -> CSIStorageCapacity
# -> DefaultPodTopologySpread
# -> GenericEphemeralVolume
# -> PreferNominatedNode
# -> RuntimeClass
# -> NetworkPolicyEndPort
# -> ProcMountType
# -> TTLAfterFinished
# -> IndexedJob
# -> JobTrackingWithFinalizers
# -> JobReadyPods
# -> KubeletPodResources
# -> CSIMigration
# -> CSIMigrationGCE
# -> InTreePluginGCEUnregister
# -> CSIMigrationAWS
# -> InTreePluginAWSUnregister
# -> CSIMigrationAzureDisk
# -> InTreePluginAzureDiskUnregister
# -> CSIMigrationAzureFile
# -> InTreePluginAzureFileUnregister
# -> CSIMigrationvSphere
# -> InTreePluginvSphereUnregister
# -> CSIMigrationOpenStack
# -> InTreePluginOpenStackUnregister
# -> CSIVolumeFSGroupPolicy
# -> ConfigurableFSGroupPolicy
# -> DelegateFSGroupToCSIDriver
# -> LocalStorageCapacityIsolationFSQuotaMonitoring
# -> NonPreemptingPriority
# -> PodOverhead
# -> IPv6DualStack
# -> EndpointSlice
# -> EndpointSliceProxying
# -> WindowsEndpointSliceProxying
# -> PodDisruptionBudget
# -> DaemonSetUpdateSurge
# -> ImmutableEphemeralVolumes
# -> HugePageStorageMediumSize
# -> DownwardAPIHugePages
# -> AnyVolumeDataSource
# -> SetHostnameAsFQDN
# -> WinOverlay
# -> WinDSR
# -> DisableAcceleratorUsageMetrics
# -> HPAContainerMetrics
# -> EndpointSliceTerminatingCondition
# -> ProxyTerminatingEndpoints
# -> EndpointSliceNodeName
# -> SizeMemoryBackedVolumes
# -> ExecProbeTimeout
# -> KubeletCredentialProviders
# -> DisableCloudProviders
# -> DisableKubeletCloudCredentialProviders
# -> CSIServiceAccountToken
# -> GracefulNodeShutdown
# -> ServiceLBNodePortControl
# -> MixedProtocolLBService
# -> VolumeCapacityPriority
# -> PodDeletionCost
# -> TopologyAwareHints
# -> ProbeTerminationGracePeriod
# -> NodeSwap
# -> PodAffinityNamespaceSelector
# -> ServiceLoadBalancerClass
# -> LogarithmicScaleDown
# -> IngressClassNamespacedParams
# -> ServiceInternalTrafficPolicy
# -> SuspendJob
# -> KubeletPodResourcesGetAllocatable
# -> NamespaceDefaultLabelName
# -> CSIVolumeHealth
# -> WindowsHostProcessContainers
# -> StatefulSetMinReadySeconds
# -> IdentifyPodOS
# -> ExpandedDNSConfig
# -> SeccompDefault
# -> PodSecurity
# -> ReadWriteOncePod
# -> CSRDuration
# -> KubeletInUserNamespace
# -> MemoryQoS
# -> CPUManagerPolicyOptions
# -> ControllerManagerLeaderMigration
# -> CPUManagerPolicyAlphaOptions
# -> CPUManagerPolicyBetaOptions
# -> JobMutableNodeSchedulingDirectives
#
#
# ./kubernetes/pkg/controller/controller_utils_test.go contains :
# -> PodDeletionCost
# -> LogarithmicScaleDown
#
#
# ./kubernetes/pkg/controller/certificates/signer/signer_test.go contains :
# -> CSRDuration
#
#
# ./kubernetes/pkg/controller/daemon/daemon_controller_test.go contains :
# -> DaemonSetUpdateSurge
#
#
# ./kubernetes/pkg/controller/daemon/update_test.go contains :
# -> DaemonSetUpdateSurge
#
#
# ./kubernetes/pkg/controller/endpointslice/reconciler_test.go contains :
# -> EndpointSlice
# -> EndpointSliceTerminatingCondition
# -> TopologyAwareHints
#
#
# ./kubernetes/pkg/controller/endpointslice/utils_test.go contains :
# -> EndpointSlice
# -> EndpointSliceTerminatingCondition
# -> TopologyAwareHints
#
#
# ./kubernetes/pkg/controller/endpointslice/endpointslice_controller_test.go contains :
# -> EndpointSlice
# -> EndpointSliceTerminatingCondition
#
#
# ./kubernetes/pkg/controller/volume/persistentvolume/pv_controller_test.go contains :
# -> CSIMigration
# -> CSIMigrationGCE
#
#
# ./kubernetes/pkg/controller/volume/attachdetach/attach_detach_controller_test.go contains :
# -> CSIMigration
# -> CSIMigrationGCE
# -> InTreePluginGCEUnregister
#
#
# ./kubernetes/pkg/controller/volume/expand/expand_controller_test.go contains :
# -> CSIMigration
# -> CSIMigrationAWS
#
#
# ./kubernetes/pkg/controller/statefulset/stateful_set_control_test.go contains :
# -> StatefulSetMinReadySeconds
#
#
# ./kubernetes/pkg/controller/statefulset/stateful_set_status_updater_test.go contains :
# -> StatefulSetMinReadySeconds
#
#
# ./kubernetes/pkg/controller/statefulset/stateful_set_control.go contains :
# -> StatefulSetMinReadySeconds
#
#
# ./kubernetes/pkg/controller/job/indexed_job_utils_test.go contains :
# -> JobTrackingWithFinalizers
# ./kubernetes/pkg/controller/job/job_controller_test.go contains :
# -> IndexedJob
# -> JobTrackingWithFinalizers
# -> JobReadyPods
# -> SuspendJob
#
#
# ./kubernetes/pkg/security/podsecuritypolicy/provider_test.go contains :
# -> AppArmor
# -> EphemeralContainers
# -> CSIInlineVolume
# -> RuntimeClass
# -> ProcMountType
# -> PodSecurity
#
#
# ./kubernetes/pkg/api/pod/util_test.go contains :
# -> AppArmor
# -> LocalStorageCapacityIsolation
# -> EphemeralContainers
# -> ProcMountType
# -> ConfigurableFSGroupPolicy
# -> PodDeletionCost
# -> ProbeTerminationGracePeriod
# -> PodAffinityNamespaceSelector
# -> IdentifyPodOS
# -> ExpandedDNSConfig
# -> PodSecurity
#
#
# ./kubernetes/pkg/api/v1/pod/util_test.go contains :
# -> EphemeralContainers
#
#
# ./kubernetes/pkg/api/persistentvolume/util_test.go contains :
# -> ExpandCSIVolumes
#
#
# ./kubernetes/pkg/api/persistentvolumeclaim/util_test.go contains :
# -> AnyVolumeDataSource
#
#
# ./kubernetes/pkg/api/podsecuritypolicy/util_test.go contains :
# -> ProcMountType
# -> PodSecurity
#
#
# ./kubernetes/pkg/proxy/topology_test.go contains :
# -> TopologyAwareHints
#
#
# ./kubernetes/pkg/proxy/ipvs/proxier_test.go contains :
# -> EndpointSlice
# -> ProxyTerminatingEndpoints
# -> ServiceInternalTrafficPolicy
#
#
# ./kubernetes/pkg/proxy/iptables/proxier_test.go contains :
# -> EndpointSlice
# -> ProxyTerminatingEndpoints
# -> ServiceInternalTrafficPolicy
#
#
# ./kubernetes/cmd/kube-controller-manager/app/plugins_providers.go contains :
# -> CSIMigration
# -> CSIMigrationGCE
# -> InTreePluginGCEUnregister
# -> CSIMigrationAWS
# -> InTreePluginAWSUnregister
# -> CSIMigrationAzureDisk
# -> InTreePluginAzureDiskUnregister
# -> CSIMigrationAzureFile
# -> InTreePluginAzureFileUnregister
# -> CSIMigrationvSphere
# -> InTreePluginvSphereUnregister
# -> CSIMigrationOpenStack
# -> InTreePluginOpenStackUnregister
#
#
# ./kubernetes/cmd/kubelet/app/server.go contains :
# -> DynamicKubeletConfig
# -> DevicePlugins
# -> QOSReserved
# -> CPUManager
# -> CPUCFSQuotaPeriod
# -> TopologyManager
# -> MemoryManager
# -> KubeletPodResources
# -> SeccompDefault
# -> MemoryQoS
# -> CPUManagerPolicyOptions
#
#
# ./kubernetes/cmd/kubelet/app/plugins_providers.go contains :
# -> CSIMigration
# -> CSIMigrationGCE
# -> InTreePluginGCEUnregister
# -> CSIMigrationAWS
# -> InTreePluginAWSUnregister
# -> CSIMigrationAzureDisk
# -> InTreePluginAzureDiskUnregister
# -> CSIMigrationAzureFile
# -> InTreePluginAzureFileUnregister
# -> CSIMigrationvSphere
# -> InTreePluginvSphereUnregister
# -> CSIMigrationOpenStack
# -> InTreePluginOpenStackUnregister
#
#
# ./kubernetes/cmd/kube-scheduler/app/server_test.go contains :
# -> DefaultPodTopologySpread
# -> VolumeCapacityPriority
#
#
# ./kubernetes/cmd/kubeadm/app/features/features.go contains :
# -> IPv6DualStack

# %%
len(go_file_interests)
# Out:
# 148

# %% [markdown]
# ## Step 3 - Search Feature Toggles dependencies in the AST

# %%
for gfi in go_file_interests:
    
    s = ""
    with open(gfi, "r") as f:
        s+=f.read()+"\n"

    print("File :            ", gfi, "\n")

    source = bytes(s, "utf8")
    ast = parser.parse(source)

    root_node = ast.root_node

    tree = Tree()

    root_node = ast.root_node

    type_nodes = dict()

    def get_name(node):
        return source[node.start_byte:node.end_byte].decode('utf8')

    def get_id(node):
        global type_nodes
        node_type = node.type
        if node_type not in type_nodes:
            type_nodes[node_type]=1
        else:
            type_nodes[node_type]+=1
        return node_type+str(type_nodes[node_type])

    def process(root_id, node):
        global tree
        node_id = get_id(node)
        node_name = get_name(node)
        for kw in keywords:
            if kw in node_name and node.type == 'if_statement':
                print("\n\n"+get_name(node)+"\n\n")
                for c in node.children:
                    if c.type == 'binary_expression' or c.type == 'unary_expression' or c.type == 'call_expression':
                        print("->",get_name(c))
        tree.create_node(node_name,
                         node_id,
                         parent = root_id)
        if len(node.children) != 0:
            for i in range(len(node.children)):
                process(node_id, node.children[i])

    tree.create_node("root", "root")
    for i in range(len(root_node.children)):
        process("root", root_node.children[i])
    print("\n")

    #tree.show()
# Out:
# File :             ./kubernetes/plugin/pkg/admission/priority/admission_test.go
#
#
#
# File :             ./kubernetes/plugin/pkg/admission/priority/admission.go
#
#
#
# File :             ./kubernetes/plugin/pkg/admission/noderestriction/admission.go
#
#
#
# File :             ./kubernetes/plugin/pkg/admission/runtimeclass/admission_test.go
#
#
#
# if featureInspection {
# 		relevantFeatures := map[featuregate.Feature]featuregate.FeatureSpec{
# 			features.PodOverhead: {Default: false},
# 		}
# 		fg := featuregate.NewFeatureGate()
# 		fg.Add(relevantFeatures)
# 		runtimeClass.InspectFeatureGates(fg)
# 	}
#
#
#
#
# if addLister {
# 		informerFactory := informers.NewSharedInformerFactory(nil, controller.NoResyncPeriodFunc())
# 		runtimeClass.SetExternalKubeInformerFactory(informerFactory)
# 		if listerObject != nil {
# 			informerFactory.Node().V1().RuntimeClasses().Informer().GetStore().Add(listerObject)
# 		}
# 	}
#
#
#
#
# if listerObject != nil {
# 			informerFactory.Node().V1().RuntimeClasses().Informer().GetStore().Add(listerObject)
# 		}
#
#
# -> listerObject != nil
#
#
# File :             ./kubernetes/plugin/pkg/admission/runtimeclass/admission.go
#
#
#
# if r.runtimeClassLister == nil {
# 		return fmt.Errorf("missing RuntimeClass lister")
# 	}
#
#
# -> r.runtimeClassLister == nil
#
#
# if r.runtimeClassClient == nil {
# 		return fmt.Errorf("missing RuntimeClass client")
# 	}
#
#
# -> r.runtimeClassClient == nil
#
#
# if pod.Spec.RuntimeClassName == nil {
# 		return pod, nil, nil
# 	}
#
#
# -> pod.Spec.RuntimeClassName == nil
#
#
# if apierrors.IsNotFound(err) {
# 		// if not found, our informer cache could be lagging, do a live lookup
# 		runtimeClass, err = r.runtimeClassClient.Get(ctx, *pod.Spec.RuntimeClassName, metav1.GetOptions{})
# 		if apierrors.IsNotFound(err) {
# 			return pod, nil, admission.NewForbidden(attributes, fmt.Errorf("pod rejected: RuntimeClass %q not found", *pod.Spec.RuntimeClassName))
# 		}
# 	}
#
#
# -> apierrors.IsNotFound(err)
#
#
# if apierrors.IsNotFound(err) {
# 			return pod, nil, admission.NewForbidden(attributes, fmt.Errorf("pod rejected: RuntimeClass %q not found", *pod.Spec.RuntimeClassName))
# 		}
#
#
# -> apierrors.IsNotFound(err)
#
#
# if pod.Spec.Overhead != nil && !apiequality.Semantic.DeepEqual(nodeOverhead.PodFixed, pod.Spec.Overhead) {
# 		return admission.NewForbidden(a, fmt.Errorf("pod rejected: Pod's Overhead doesn't match RuntimeClass's defined Overhead"))
# 	}
#
#
# -> pod.Spec.Overhead != nil && !apiequality.Semantic.DeepEqual(nodeOverhead.PodFixed, pod.Spec.Overhead)
#
#
# if runtimeClass != nil && runtimeClass.Overhead != nil {
# 		// If the Overhead set doesn't match what is provided in the RuntimeClass definition, reject the pod
# 		nodeOverhead := &node.Overhead{}
# 		if err := apinodev1.Convert_v1_Overhead_To_node_Overhead(runtimeClass.Overhead, nodeOverhead, nil); err != nil {
# 			return err
# 		}
# 		if !apiequality.Semantic.DeepEqual(nodeOverhead.PodFixed, pod.Spec.Overhead) {
# 			return admission.NewForbidden(a, fmt.Errorf("pod rejected: Pod's Overhead doesn't match RuntimeClass's defined Overhead"))
# 		}
# 	} else {
# 		// If RuntimeClass with Overhead is not defined but an Overhead is set for pod, reject the pod
# 		if pod.Spec.Overhead != nil {
# 			return admission.NewForbidden(a, fmt.Errorf("pod rejected: Pod Overhead set without corresponding RuntimeClass defined Overhead"))
# 		}
# 	}
#
#
# -> runtimeClass != nil && runtimeClass.Overhead != nil
#
#
# if !apiequality.Semantic.DeepEqual(nodeOverhead.PodFixed, pod.Spec.Overhead) {
# 			return admission.NewForbidden(a, fmt.Errorf("pod rejected: Pod's Overhead doesn't match RuntimeClass's defined Overhead"))
# 		}
#
#
# -> !apiequality.Semantic.DeepEqual(nodeOverhead.PodFixed, pod.Spec.Overhead)
#
#
# if pod.Spec.Overhead != nil {
# 			return admission.NewForbidden(a, fmt.Errorf("pod rejected: Pod Overhead set without corresponding RuntimeClass defined Overhead"))
# 		}
#
#
# -> pod.Spec.Overhead != nil
#
#
# File :             ./kubernetes/plugin/pkg/admission/resourcequota/admission_test.go
#
#
#
# File :             ./kubernetes/plugin/pkg/admission/security/podsecurity/admission_test.go
#
#
#
# File :             ./kubernetes/plugin/pkg/admission/security/podsecurity/admission.go
#
#
#
# if err != nil {
# 		return nil, fmt.Errorf("could not create PodSecurityRegistry: %w", err)
# 	}
#
#
# -> err != nil
#
#
# if !result.Allowed {
# 		// start with a generic forbidden error
# 		retval := admission.NewForbidden(a, errors.New("Not allowed by PodSecurity")).(*apierrors.StatusError)
# 		// use message/reason/details/code from admission library if populated
# 		if result.Result != nil {
# 			if len(result.Result.Message) > 0 {
# 				retval.ErrStatus.Message = result.Result.Message
# 			}
# 			if len(result.Result.Reason) > 0 {
# 				retval.ErrStatus.Reason = result.Result.Reason
# 			}
# 			if result.Result.Details != nil {
# 				retval.ErrStatus.Details = result.Result.Details
# 			}
# 			if result.Result.Code != 0 {
# 				retval.ErrStatus.Code = result.Result.Code
# 			}
# 		}
# 		return retval
# 	}
#
#
# -> !result.Allowed
#
#
# File :             ./kubernetes/plugin/pkg/admission/security/podsecuritypolicy/admission_test.go
#
#
#
# File :             ./kubernetes/plugin/pkg/auth/authorizer/node/node_authorizer.go
#
#
#
# if attrs.IsResourceRequest() {
# 		requestResource := schema.GroupResource{Group: attrs.GetAPIGroup(), Resource: attrs.GetResource()}
# 		switch requestResource {
# 		case secretResource:
# 			return r.authorizeReadNamespacedObject(nodeName, secretVertexType, attrs)
# 		case configMapResource:
# 			return r.authorizeReadNamespacedObject(nodeName, configMapVertexType, attrs)
# 		case pvcResource:
# 			if r.features.Enabled(features.ExpandPersistentVolumes) {
# 				if attrs.GetSubresource() == "status" {
# 					return r.authorizeStatusUpdate(nodeName, pvcVertexType, attrs)
# 				}
# 			}
# 			return r.authorizeGet(nodeName, pvcVertexType, attrs)
# 		case pvResource:
# 			return r.authorizeGet(nodeName, pvVertexType, attrs)
# 		case vaResource:
# 			return r.authorizeGet(nodeName, vaVertexType, attrs)
# 		case svcAcctResource:
# 			return r.authorizeCreateToken(nodeName, serviceAccountVertexType, attrs)
# 		case leaseResource:
# 			return r.authorizeLease(nodeName, attrs)
# 		case csiNodeResource:
# 			return r.authorizeCSINode(nodeName, attrs)
# 		}
#
# 	}
#
#
# -> attrs.IsResourceRequest()
#
#
# if r.features.Enabled(features.ExpandPersistentVolumes) {
# 				if attrs.GetSubresource() == "status" {
# 					return r.authorizeStatusUpdate(nodeName, pvcVertexType, attrs)
# 				}
# 			}
#
#
# -> r.features.Enabled(features.ExpandPersistentVolumes)
#
#
# File :             ./kubernetes/staging/src/k8s.io/controller-manager/pkg/leadermigration/options/options_test.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/controller-manager/pkg/features/kube_features.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures_appArmorProfile.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures_procMount.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/pod-security-admission/test/fixtures_windowsHostProcess.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/pod-security-admission/test/run.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/legacy-cloud-providers/azure/azure_standard.go
#
#
#
# File :             ./kubernetes/staging/src/k8s.io/legacy-cloud-providers/azure/azure.go
#
#
#
# File :             ./kubernetes/test/e2e/framework/util.go
#
#
#
# if !utilfeature.DefaultFeatureGate.Enabled(FeatureEphemeralContainers) {
# 		containerType &= ^EphemeralContainers
# 	}
#
#
# -> !utilfeature.DefaultFeatureGate.Enabled(FeatureEphemeralContainers)
#
#
# if mask&EphemeralContainers != 0 {
# 		for i := range podSpec.EphemeralContainers {
# 			if !visitor((*v1.Container)(&podSpec.EphemeralContainers[i].EphemeralContainerCommon), EphemeralContainers) {
# 				return false
# 			}
# 		}
# 	}
#
#
# -> mask&EphemeralContainers != 0
#
#
# if !visitor((*v1.Container)(&podSpec.EphemeralContainers[i].EphemeralContainerCommon), EphemeralContainers) {
# 				return false
# 			}
#
#
# -> !visitor((*v1.Container)(&podSpec.EphemeralContainers[i].EphemeralContainerCommon), EphemeralContainers)
#
#
# File :             ./kubernetes/test/e2e/framework/skipper/skipper.go
#
#
#
# File :             ./kubernetes/test/integration/dryrun/dryrun_test.go
#
#
#
# File :             ./kubernetes/test/integration/scheduler/predicates_test.go
# File :             ./kubernetes/test/integration/scheduler/preemption_test.go
#
#
#
# File :             ./kubernetes/test/integration/scheduler/priorities_test.go
#
#
#
# File :             ./kubernetes/test/integration/quota/quota_test.go
#
#
#
# File :             ./kubernetes/test/integration/endpointslice/endpointsliceterminating_test.go
#
#
#
# File :             ./kubernetes/test/integration/pods/pods_test.go
#
#
#
# if _, err := setUpEphemeralContainers(client.CoreV1().Pods(ns.Name), pod, tc.original); err != nil {
# 			t.Errorf("%v: %v", tc.name, err)
# 		}
#
#
# -> err != nil
#
#
# if _, err := client.CoreV1().Pods(ns.Name).UpdateEphemeralContainers(context.TODO(), pod.Name, pod, metav1.UpdateOptions{}); tc.valid && err != nil {
# 			t.Errorf("%v: failed to update ephemeral containers: %v", tc.name, err)
# 		} else if !tc.valid && err == nil {
# 			t.Errorf("%v: unexpected allowed update to ephemeral containers", tc.name)
# 		}
#
#
# -> tc.valid && err != nil
#
#
# if _, err = client.CoreV1().Pods(ns.Name).UpdateEphemeralContainers(context.TODO(), pod.Name, pod, metav1.UpdateOptions{}); err == nil {
# 		t.Fatalf("got nil error when updating ephemeral containers with feature disabled, wanted %q", metav1.StatusReasonNotFound)
# 	}
#
#
# -> err == nil
#
#
# File :             ./kubernetes/test/integration/service/loadbalancer_test.go
#
#
#
# File :             ./kubernetes/test/integration/auth/node_test.go
#
#
#
# File :             ./kubernetes/test/integration/auth/podsecurity_test.go
#
#
#
# File :             ./kubernetes/test/integration/scheduler_perf/scheduler_perf_legacy_test.go
#
#
#
# File :             ./kubernetes/test/integration/replicationcontroller/replicationcontroller_test.go
#
#
#
# File :             ./kubernetes/test/integration/volumescheduling/volume_binding_test.go
#
#
#
# if test.haveCapacity {
# 			if _, err := config.client.StorageV1beta1().CSIStorageCapacities("default").Create(context.TODO(),
# 				&storagev1beta1.CSIStorageCapacity{
# 					ObjectMeta: metav1.ObjectMeta{
# 						GenerateName: "foo-",
# 					},
# 					StorageClassName: classes[classWait].Name,
# 					NodeTopology:     &metav1.LabelSelector{},
# 					// More than the 5Gi used in makePVC.
# 					Capacity: resource.NewQuantity(6*1024*1024*1024, resource.BinarySI),
# 				},
# 				metav1.CreateOptions{}); err != nil {
# 				t.Fatalf("Failed to create CSIStorageCapacity: %v", err)
# 			}
# 		}
#
#
#
#
# if _, err := config.client.StorageV1beta1().CSIStorageCapacities("default").Create(context.TODO(),
# 				&storagev1beta1.CSIStorageCapacity{
# 					ObjectMeta: metav1.ObjectMeta{
# 						GenerateName: "foo-",
# 					},
# 					StorageClassName: classes[classWait].Name,
# 					NodeTopology:     &metav1.LabelSelector{},
# 					// More than the 5Gi used in makePVC.
# 					Capacity: resource.NewQuantity(6*1024*1024*1024, resource.BinarySI),
# 				},
# 				metav1.CreateOptions{}); err != nil {
# 				t.Fatalf("Failed to create CSIStorageCapacity: %v", err)
# 			}
#
#
# -> err != nil
#
#
# File :             ./kubernetes/test/integration/volumescheduling/volume_capacity_priority_test.go
#
#
#
# File :             ./kubernetes/test/integration/replicaset/replicaset_test.go
#
#
#
# if len(tc.costs) != 0 {
# 					updatePod(t, podClient, podName, func(pod *v1.Pod) {
# 						pod.Annotations = map[string]string{core.PodDeletionCost: tc.costs[i]}
# 					})
# 				}
#
#
# -> len(tc.costs) != 0
#
#
# File :             ./kubernetes/test/integration/statefulset/statefulset_test.go
#
#
#
# File :             ./kubernetes/test/integration/apiserver/apiserver_test.go
#
#
#
# File :             ./kubernetes/test/integration/apiserver/print_test.go
#
#
#
# File :             ./kubernetes/test/integration/job/job_test.go
#
#
#
# if err := waitForEvent(events, jobObj.UID, "IndexedJobDisabled"); err != nil {
# 				t.Errorf("Waiting for an event for IndexedJobDisabled: %v", err)
# 			}
#
#
# -> err != nil
#
#
# File :             ./kubernetes/test/e2e_node/util.go
#
#
#
# if err != nil {
# 		return false, fmt.Errorf("could not determine whether 'DynamicKubeletConfig' feature is enabled, err: %v", err)
# 	}
#
#
# -> err != nil
#
#
# if configEnabled, err := isKubeletConfigEnabled(f); err != nil {
# 		return err
# 	} else if !configEnabled {
# 		return fmt.Errorf("The Dynamic Kubelet Configuration feature is not enabled.\n" +
# 			"Pass --feature-gates=DynamicKubeletConfig=true to the Kubelet to enable this feature.\n" +
# 			"For `make test-e2e-node`, you can set `TEST_ARGS='--feature-gates=DynamicKubeletConfig=true'`.")
# 	}
#
#
# -> err != nil
#
#
# if !configEnabled {
# 		return fmt.Errorf("The Dynamic Kubelet Configuration feature is not enabled.\n" +
# 			"Pass --feature-gates=DynamicKubeletConfig=true to the Kubelet to enable this feature.\n" +
# 			"For `make test-e2e-node`, you can set `TEST_ARGS='--feature-gates=DynamicKubeletConfig=true'`.")
# 	}
#
#
# -> !configEnabled
#
#
# File :             ./kubernetes/pkg/apis/scheduling/v1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/scheduling/v1beta1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/scheduling/v1alpha1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/scheduling/util/util_test.go
#
#
#
# if !reflect.DeepEqual(newPriorityClass, pcWithoutNonPreemptingPriority()) {
# 							t.Errorf("new PriorityClass had PriorityClassNonPreemptingPriority: %v", diff.ObjectReflectDiff(newPriorityClass, pcWithoutNonPreemptingPriority()))
# 						}
#
#
# -> !reflect.DeepEqual(newPriorityClass, pcWithoutNonPreemptingPriority())
#
#
# File :             ./kubernetes/pkg/apis/core/v1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/core/pods/helpers_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/core/validation/conditional_validation_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/core/validation/validation_test.go
#
#
#
# if errs := validateEphemeralContainers(ephemeralContainers, containers, initContainers, vols, field.NewPath("ephemeralContainers"), PodValidationOptions{}); len(errs) != 0 {
# 			t.Errorf("expected success for '%s' but got errors: %v", title, errs)
# 		}
#
#
# -> len(errs) != 0
#
#
# if errs := ValidatePodCreate(&v.spec, PodValidationOptions{AllowInvalidPodDeletionCost: false}); len(errs) == 0 {
# 				t.Errorf("expected failure")
# 			} else if v.expectedError == "" {
# 				t.Errorf("missing expectedError, got %q", errs.ToAggregate().Error())
# 			} else if actualError := errs.ToAggregate().Error(); !strings.Contains(actualError, v.expectedError) {
# 				t.Errorf("expected error to contain %q, got %q", v.expectedError, actualError)
# 			}
#
#
# -> len(errs) == 0
#
#
# File :             ./kubernetes/pkg/apis/storage/v1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/storage/v1beta1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/storage/validation/validation_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/storage/util/util_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/apps/validation/validation_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/autoscaling/validation/validation_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/batch/v1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/networking/v1/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/apis/networking/validation/validation_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/generic_scheduler_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/apis/config/v1beta2/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/apis/config/v1beta2/default_plugins_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/apis/config/validation/validation_pluginargs_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/apis/config/v1beta3/defaults_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/apis/config/v1beta3/default_plugins_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/framework/plugins/volumerestrictions/volume_restrictions_test.go
#
#
#
# File :             ./kubernetes/pkg/scheduler/framework/plugins/nodevolumelimits/csi_test.go
#
#
#
# if test.migrationEnabled {
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, true)()
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, true)()
# 				enableMigrationOnNode(csiNode, csilibplugins.AWSEBSInTreePluginName)
# 			} else {
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, false)()
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, false)()
# 			}
#
#
#
#
# if test.migrationEnabled {
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, true)()
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, true)()
# 				enableMigrationOnNode(csiNode, csilibplugins.AWSEBSInTreePluginName)
# 			} else {
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, false)()
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, false)()
# 			}
#
#
#
#
# File :             ./kubernetes/pkg/scheduler/framework/plugins/noderesources/fit_test.go
# File :             ./kubernetes/pkg/scheduler/framework/plugins/volumebinding/binder_test.go
#
#
#
# if len(csiStorageCapacity) > 0 && csiStorageCapacity[0] {
# 		capacityCheck = &CapacityCheck{
# 			CSIDriverInformer:          csiDriverInformer,
# 			CSIStorageCapacityInformer: csiStorageCapacityInformer,
# 		}
# 	}
#
#
# -> len(csiStorageCapacity) > 0 && csiStorageCapacity[0]
#
#
# if scenario.needsCapacity && csiStorageCapacity &&
# 			csiDriver != nil && csiDriver.Spec.StorageCapacity != nil && *csiDriver.Spec.StorageCapacity {
# 			// Without CSIStorageCapacity objects, provisioning is blocked.
# 			expectedReasons = append(expectedReasons, ErrReasonNotEnoughSpace)
# 			expectedProvisions = nil
# 		}
#
#
# -> scenario.needsCapacity && csiStorageCapacity &&
# 			csiDriver != nil && csiDriver.Spec.StorageCapacity != nil && *csiDriver.Spec.StorageCapacity
#
#
# File :             ./kubernetes/pkg/quota/v1/evaluator/core/pods_test.go
#
#
#
# File :             ./kubernetes/pkg/quota/v1/evaluator/core/services_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/volume_linux_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/csi/csi_mounter_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/csi/csi_plugin_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/csi/csi_attacher_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/csi/csi_client_test.go
#
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.CSIVolumeHealth) && isSupportNodeVolumeCondition {
# 		abnormal, message := resp.VolumeCondition.GetAbnormal(), resp.VolumeCondition.GetMessage()
# 		metrics.Abnormal, metrics.Message = &abnormal, &message
# 	}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.CSIVolumeHealth) && isSupportNodeVolumeCondition
#
#
# File :             ./kubernetes/pkg/volume/csi/csi_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/csimigration/plugin_manager.go
#
#
#
# if !pm.featureGate.Enabled(features.CSIMigration) {
# 		return false
# 	}
#
#
# -> !pm.featureGate.Enabled(features.CSIMigration)
#
#
# if f.Enabled(pluginMigration) && !f.Enabled(features.CSIMigration) {
# 		return false, fmt.Errorf("enabling %q requires CSIMigration to be enabled", pluginMigration)
# 	}
#
#
# -> f.Enabled(pluginMigration) && !f.Enabled(features.CSIMigration)
#
#
# File :             ./kubernetes/pkg/volume/csimigration/plugin_manager_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/emptydir/empty_dir_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/util/util_test.go
#
#
#
# File :             ./kubernetes/pkg/volume/util/fsquota/quota_linux_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/apis/podresources/server_v1_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/container/helpers_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/server/stats/volume_stat_calculator_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_manager_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_sandbox_test.go
#
#
#
# if podFieldProfile != nil {
# 		pod.Spec.SecurityContext = &v1.PodSecurityContext{
# 			SeccompProfile: podFieldProfile,
# 		}
# 	}
#
#
# -> podFieldProfile != nil
#
#
# File :             ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_container_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/kuberuntime/kuberuntime_container_linux_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/kuberuntime/helpers_linux_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/network/dns/dns_test.go
#
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.ExpandedDNSConfig) {
# 		maxDNSSearchPaths = validation.MaxDNSSearchPathsExpanded
# 	}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.ExpandedDNSConfig)
#
#
# File :             ./kubernetes/pkg/kubelet/dockershim/exec_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/volumemanager/reconciler/reconciler_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/volumemanager/populator/desired_state_of_world_populator_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/eviction/eviction_manager_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/eviction/helpers_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/nodeshutdown/nodeshutdown_manager_linux_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/cm/helpers_linux_test.go
#
#
#
# File :             ./kubernetes/pkg/kubelet/cm/cpumanager/policy_options_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/certificates/certificates/strategy_test.go
#
#
#
# if tc.disableFeatureGate {
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSRDuration, false)()
# 			}
#
#
#
#
# File :             ./kubernetes/pkg/registry/certificates/certificates/storage/metrics_test.go
#
#
#
# if tt.disableFeatureGate {
# 				defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSRDuration, false)()
# 			} else {
# 				t.Parallel()
# 			}
#
#
#
#
# File :             ./kubernetes/pkg/registry/core/pod/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/namespace/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/service/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/service/storage/storage_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/persistentvolumeclaim/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/persistentvolumeclaim/storage/storage_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/resourcequota/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/core/node/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/storage/csidriver/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/storage/csistoragecapacity/strategy_test.go
#
#
#
# if !Strategy.NamespaceScoped() {
# 		t.Errorf("CSIStorageCapacity must be namespace scoped")
# 	}
#
#
# -> !Strategy.NamespaceScoped()
#
#
# if Strategy.AllowCreateOnUpdate() {
# 		t.Errorf("CSIStorageCapacity should not allow create on update")
# 	}
#
#
# -> Strategy.AllowCreateOnUpdate()
#
#
# File :             ./kubernetes/pkg/registry/storage/volumeattachment/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/apps/daemonset/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/apps/statefulset/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/autoscaling/horizontalpodautoscaler/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/discovery/endpointslice/strategy_test.go
#
#
#
# if !apiequality.Semantic.DeepEqual(testcase.eps, testcase.expectedEPS) {
# 				t.Logf("actual endpointslice: %v", testcase.eps)
# 				t.Logf("expected endpointslice: %v", testcase.expectedEPS)
# 				t.Errorf("unexpected EndpointSlice on create API strategy")
# 			}
#
#
# -> !apiequality.Semantic.DeepEqual(testcase.eps, testcase.expectedEPS)
#
#
# if !apiequality.Semantic.DeepEqual(testcase.newEPS, testcase.expectedEPS) {
# 				t.Logf("actual endpointslice: %v", testcase.newEPS)
# 				t.Logf("expected endpointslice: %v", testcase.expectedEPS)
# 				t.Errorf("unexpected EndpointSlice from update API strategy")
# 			}
#
#
# -> !apiequality.Semantic.DeepEqual(testcase.newEPS, testcase.expectedEPS)
#
#
# if !apiequality.Semantic.DeepEqual(tc.newEPS, tc.expectedEPS) {
# 				t.Logf("actual endpointslice: %v", tc.newEPS)
# 				t.Logf("expected endpointslice: %v", tc.expectedEPS)
# 				t.Errorf("unexpected EndpointSlice on API topology strategy")
# 			}
#
#
# -> !apiequality.Semantic.DeepEqual(tc.newEPS, tc.expectedEPS)
#
#
# File :             ./kubernetes/pkg/registry/batch/job/strategy_test.go
#
#
#
# if indexedJobEnabled != (job.Spec.CompletionMode != nil) {
# 		t.Errorf("Job should allow setting .spec.completionMode only when %v feature is enabled", features.IndexedJob)
# 	}
#
#
# -> indexedJobEnabled != (job.Spec.CompletionMode != nil)
#
#
# if !suspendJobEnabled && (job.Spec.Suspend != nil) {
# 		t.Errorf("Job should allow setting .spec.suspend only when %v feature is enabled", features.SuspendJob)
# 	}
#
#
# -> !suspendJobEnabled && (job.Spec.Suspend != nil)
#
#
# if !suspendJobEnabled && *updatedJob.Spec.Suspend {
# 		t.Errorf("[SuspendJob=%v] .spec.suspend should not be updated from false to true", suspendJobEnabled)
# 	}
#
#
# -> !suspendJobEnabled && *updatedJob.Spec.Suspend
#
#
# if !suspendJobEnabled && updatedJob.Spec.Suspend != nil {
# 		t.Errorf("[SuspendJob=%v] .spec.suspend should not be updated from nil to non-nil", suspendJobEnabled)
# 	}
#
#
# -> !suspendJobEnabled && updatedJob.Spec.Suspend != nil
# File :             ./kubernetes/pkg/registry/networking/networkpolicy/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/registry/networking/ingressclass/strategy_test.go
#
#
#
# File :             ./kubernetes/pkg/features/kube_features.go
#
#
#
# File :             ./kubernetes/pkg/controller/controller_utils_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/certificates/signer/signer_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/daemon/daemon_controller_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/daemon/update_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/endpointslice/reconciler_test.go
#
#
#
# if len(slices) != len(testCase.expectedEndpointPerSlice) {
# 				t.Fatalf("Expected %v EndpointSlice, got %d", len(testCase.expectedEndpointPerSlice), len(slices))
# 			}
#
#
# -> len(slices) != len(testCase.expectedEndpointPerSlice)
#
#
# if !strings.HasPrefix(slice.Name, testCase.service.Name) {
# 					t.Fatalf("Expected EndpointSlice name to start with %s, got %s", testCase.service.Name, slice.Name)
# 				}
#
#
# -> !strings.HasPrefix(slice.Name, testCase.service.Name)
#
#
# if !reflect.DeepEqual(testCase.expectedLabels, slice.Labels) {
# 					t.Errorf("Expected EndpointSlice to have labels: %v , got %v", testCase.expectedLabels, slice.Labels)
# 				}
#
#
# -> !reflect.DeepEqual(testCase.expectedLabels, slice.Labels)
#
#
# if slice.Labels[discovery.LabelServiceName] != testCase.service.Name {
# 					t.Fatalf("Expected EndpointSlice to have label set with %s value, got %s", testCase.service.Name, slice.Labels[discovery.LabelServiceName])
# 				}
#
#
# -> slice.Labels[discovery.LabelServiceName] != testCase.service.Name
#
#
# if slice.Annotations[corev1.EndpointsLastChangeTriggerTime] != triggerTime.Format(time.RFC3339Nano) {
# 					t.Fatalf("Expected EndpointSlice trigger time annotation to be %s, got %s", triggerTime.Format(time.RFC3339Nano), slice.Annotations[corev1.EndpointsLastChangeTriggerTime])
# 				}
#
#
# -> slice.Annotations[corev1.EndpointsLastChangeTriggerTime] != triggerTime.Format(time.RFC3339Nano)
#
#
# if !ok {
# 			t.Errorf("Expected label \"foo\" from parent service not found")
# 		} else if "bar" != w {
# 			t.Errorf("Expected EndpointSlice to have parent service labels: have %s value, expected bar", w)
# 		}
#
#
# -> !ok
#
#
# if "bar" != w {
# 			t.Errorf("Expected EndpointSlice to have parent service labels: have %s value, expected bar", w)
# 		}
#
#
# -> "bar" != w
#
#
# if i%30 == 0 {
# 			existingSlices = append(existingSlices, newEmptyEndpointSlice(sliceNum, namespace, endpointMeta, svc))
# 		}
#
#
# -> i%30 == 0
#
#
# if tc.expectChanges {
# 				if len(client.Actions()) != numActionsBefore+2 {
# 					t.Fatalf("Expected 2 additional actions, got %d", len(client.Actions())-numActionsBefore)
# 				}
#
# 				expectAction(t, client.Actions(), numActionsBefore, "create", "endpointslices")
# 				expectAction(t, client.Actions(), numActionsBefore+1, "delete", "endpointslices")
#
# 				fetchedSlices := fetchEndpointSlices(t, client, namespace)
#
# 				if len(fetchedSlices) != 1 {
# 					t.Fatalf("Expected 1 EndpointSlice to exist, got %d", len(fetchedSlices))
# 				}
# 			} else {
# 				if len(client.Actions()) != numActionsBefore {
# 					t.Errorf("Expected no additional actions, got %d", len(client.Actions())-numActionsBefore)
# 				}
# 			}
#
#
#
#
# if len(fetchedSlices) != 1 {
# 					t.Fatalf("Expected 1 EndpointSlice to exist, got %d", len(fetchedSlices))
# 				}
#
#
# -> len(fetchedSlices) != 1
#
#
# if err != nil {
# 				t.Fatalf("Expected no error creating EndpointSlice during test setup, got %v", err)
# 			}
#
#
# -> err != nil
#
#
# if err != nil {
# 				t.Fatalf("Expected no error creating EndpointSlice during test setup, got %v", err)
# 			}
#
#
# -> err != nil
#
#
# if epSlice.Name == esToUpdate.Name {
# 					updatedSliceFound = true
# 					if tc.attemptUpdate && len(epSlice.Endpoints) != len(esToUpdate.Endpoints) {
# 						t.Errorf("Expected EndpointSlice to be updated with %d endpoints, got %d endpoints", len(esToUpdate.Endpoints), len(epSlice.Endpoints))
# 					}
# 				}
#
#
# -> epSlice.Name == esToUpdate.Name
#
#
# if tc.attemptUpdate && len(epSlice.Endpoints) != len(esToUpdate.Endpoints) {
# 						t.Errorf("Expected EndpointSlice to be updated with %d endpoints, got %d endpoints", len(esToUpdate.Endpoints), len(epSlice.Endpoints))
# 					}
#
#
# -> tc.attemptUpdate && len(epSlice.Endpoints) != len(esToUpdate.Endpoints)
#
#
# if createdSliceFound != tc.expectCreatedSlice {
# 				t.Errorf("Expected created EndpointSlice existence to be %t, got %t", tc.expectCreatedSlice, createdSliceFound)
# 			}
#
#
# -> createdSliceFound != tc.expectCreatedSlice
#
#
# if updatedSliceFound != tc.expectUpdatedSlice {
# 				t.Errorf("Expected updated EndpointSlice existence to be %t, got %t", tc.expectUpdatedSlice, updatedSliceFound)
# 			}
#
#
# -> updatedSliceFound != tc.expectUpdatedSlice
#
#
# if deletedSliceFound != tc.expectDeletedSlice {
# 				t.Errorf("Expected deleted EndpointSlice existence to be %t, got %t", tc.expectDeletedSlice, deletedSliceFound)
# 			}
#
#
# -> deletedSliceFound != tc.expectDeletedSlice
#
#
# if !ok {
# 		t.Fatalf("Expected Service to be tracked for EndpointSlices %s", slice.Name)
# 	}
#
#
# -> !ok
#
#
# if !ok {
# 		t.Fatalf("Expected EndpointSlice %s to be tracked", slice.Name)
# 	}
#
#
# -> !ok
#
#
# if err != nil {
# 		t.Fatalf("Expected no error fetching Endpoint Slices, got: %v", err)
# 		return []discovery.EndpointSlice{}
# 	}
#
#
# -> err != nil
#
#
# if actualDesiredSlices != float64(em.desiredSlices) {
# 		t.Errorf("Expected desiredEndpointSlices to be %d, got %v", em.desiredSlices, actualDesiredSlices)
# 	}
#
#
# -> actualDesiredSlices != float64(em.desiredSlices)
#
#
# if actualDesiredSlices != float64(em.desiredSlices) {
# 		t.Errorf("Expected numEndpointSlices to be %d, got %v", em.actualSlices, actualNumSlices)
# 	}
#
#
# -> actualDesiredSlices != float64(em.desiredSlices)
#
#
# File :             ./kubernetes/pkg/controller/endpointslice/utils_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/endpointslice/endpointslice_controller_test.go
#
#
#
# if err != nil {
# 			t.Fatalf("Expected no error adding EndpointSlice: %v", err)
# 		}
#
#
# -> err != nil
#
#
# if err != nil {
# 			t.Fatalf("Expected no error creating EndpointSlice: %v", err)
# 		}
#
#
# -> err != nil
#
#
# if err != nil {
# 				t.Fatalf("Expected no error adding EndpointSlice: %v", err)
# 			}
#
#
# -> err != nil
#
#
# File :             ./kubernetes/pkg/controller/volume/persistentvolume/pv_controller_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/volume/attachdetach/attach_detach_controller_test.go
#
#
#
# if tc.csiMigration {
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, tc.csiMigration)()
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationGCE, tc.csiMigration)()
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.InTreePluginGCEUnregister, tc.csiMigration)()
#
# 		// if InTreePluginGCEUnregister is enabled, only the CSI plugin is registered but not the in-tree one
# 		plugins = append(plugins, csi.ProbeVolumePlugins()...)
# 	} else {
# 		plugins = controllervolumetesting.CreateTestPlugin()
# 	}
#
#
#
#
# if tc.csiMigration {
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, tc.csiMigration)()
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationGCE, tc.csiMigration)()
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.InTreePluginGCEUnregister, tc.csiMigration)()
#
# 		// if InTreePluginGCEUnregister is enabled, only the CSI plugin is registered but not the in-tree one
# 		plugins = append(plugins, csi.ProbeVolumePlugins()...)
# 	} else {
# 		plugins = controllervolumetesting.CreateTestPlugin()
# 	}
#
#
#
#
# if tc.csiMigration {
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, tc.csiMigration)()
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationGCE, tc.csiMigration)()
# 		defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.InTreePluginGCEUnregister, tc.csiMigration)()
#
# 		// if InTreePluginGCEUnregister is enabled, only the CSI plugin is registered but not the in-tree one
# 		plugins = append(plugins, csi.ProbeVolumePlugins()...)
# 	} else {
# 		plugins = controllervolumetesting.CreateTestPlugin()
# 	}
#
#
#
#
# File :             ./kubernetes/pkg/controller/volume/expand/expand_controller_test.go
#
#
#
# if test.csiMigrationEnabled {
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, true)()
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, true)()
# 		} else {
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, false)()
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, false)()
# 		}
#
#
#
#
# if test.csiMigrationEnabled {
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, true)()
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, true)()
# 		} else {
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigration, false)()
# 			defer featuregatetesting.SetFeatureGateDuringTest(t, utilfeature.DefaultFeatureGate, features.CSIMigrationAWS, false)()
# 		}
#
#
#
#
# File :             ./kubernetes/pkg/controller/statefulset/stateful_set_control_test.go
# File :             ./kubernetes/pkg/controller/statefulset/stateful_set_status_updater_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/statefulset/stateful_set_control.go
#
#
#
# if isRunningAndReady(pods[i]) {
# 			status.ReadyReplicas++
# 			// count the number of running and available replicas
# 			if utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds) {
# 				if isRunningAndAvailable(pods[i], set.Spec.MinReadySeconds) {
# 					status.AvailableReplicas++
# 				}
# 			} else {
# 				// If the featuregate is not enabled, all the ready replicas should be considered as available replicas
# 				status.AvailableReplicas = status.ReadyReplicas
# 			}
# 		}
#
#
# -> isRunningAndReady(pods[i])
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds) {
# 				if isRunningAndAvailable(pods[i], set.Spec.MinReadySeconds) {
# 					status.AvailableReplicas++
# 				}
# 			} else {
# 				// If the featuregate is not enabled, all the ready replicas should be considered as available replicas
# 				status.AvailableReplicas = status.ReadyReplicas
# 			}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds)
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds) && !isRunningAndAvailable(replicas[i], set.Spec.MinReadySeconds) && monotonic {
# 			klog.V(4).Infof(
# 				"StatefulSet %s/%s is waiting for Pod %s to be Available",
# 				set.Namespace,
# 				set.Name,
# 				replicas[i].Name)
# 			return &status, nil
# 		}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds) && !isRunningAndAvailable(replicas[i], set.Spec.MinReadySeconds) && monotonic
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds) && !isRunningAndAvailable(condemned[target], set.Spec.MinReadySeconds) && monotonic && condemned[target] != firstUnhealthyPod {
# 			klog.V(4).Infof(
# 				"StatefulSet %s/%s is waiting for Pod %s to be Available prior to scale down",
# 				set.Namespace,
# 				set.Name,
# 				firstUnhealthyPod.Name)
# 			return &status, nil
# 		}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.StatefulSetMinReadySeconds) && !isRunningAndAvailable(condemned[target], set.Spec.MinReadySeconds) && monotonic && condemned[target] != firstUnhealthyPod
#
#
# File :             ./kubernetes/pkg/controller/job/indexed_job_utils_test.go
#
#
#
# File :             ./kubernetes/pkg/controller/job/job_controller_test.go
#
#
#
# if tc.completionMode == batch.IndexedCompletion {
# 					checkIndexedJobPods(t, &fakePodControl, tc.expectedCreatedIndexes, job.Name)
# 				} else {
# 					for _, p := range fakePodControl.Templates {
# 						// Fake pod control doesn't add generate name from the owner reference.
# 						if p.GenerateName != "" {
# 							t.Errorf("Got pod generate name %s, want %s", p.GenerateName, "")
# 						}
# 						if p.Spec.Hostname != "" {
# 							t.Errorf("Got pod hostname %q, want none", p.Spec.Hostname)
# 						}
# 					}
# 				}
#
#
# -> tc.completionMode == batch.IndexedCompletion
#
#
# File :             ./kubernetes/pkg/security/podsecuritypolicy/provider_test.go
#
#
#
# if test.expectErr {
# 				assert.NotEmpty(t, errs, "expected validation error for ephemeral containers")
# 			} else {
# 				assert.Empty(t, errs, "expected no validation errors for ephemeral containers")
# 				ape := ecPod.Spec.EphemeralContainers[0].SecurityContext.AllowPrivilegeEscalation
# 				assert.Equal(t, test.expectAPE, ape, "expected pod AllowPrivilegeEscalation for ephemeral container")
# 			}
#
#
#
#
# File :             ./kubernetes/pkg/api/pod/util_test.go
#
#
#
# if oldPod != nil {
# 				if podInfo.newPodHasFSGroupChangePolicy {
# 					newPod.Spec.SecurityContext = &api.PodSecurityContext{
# 						FSGroup:             &podFSGroup,
# 						FSGroupChangePolicy: &changePolicy,
# 					}
# 				} else {
# 					newPod.Spec.SecurityContext = &api.PodSecurityContext{}
# 				}
# 			}
#
#
# -> oldPod != nil
#
#
# if podInfo.newPodHasFSGroupChangePolicy {
# 					newPod.Spec.SecurityContext = &api.PodSecurityContext{
# 						FSGroup:             &podFSGroup,
# 						FSGroupChangePolicy: &changePolicy,
# 					}
# 				} else {
# 					newPod.Spec.SecurityContext = &api.PodSecurityContext{}
# 				}
#
#
#
#
# if !reflect.DeepEqual(newPod, podWithoutAppArmor()) {
# 							t.Errorf("new pod had EmptyDir SizeLimit: %v", cmp.Diff(newPod, podWithoutAppArmor()))
# 						}
#
#
# -> !reflect.DeepEqual(newPod, podWithoutAppArmor())
#
#
# if !reflect.DeepEqual(newPod, podWithoutEphemeralContainers()) {
# 							t.Errorf("new pod had subpaths: %v", cmp.Diff(newPod, podWithoutEphemeralContainers()))
# 						}
#
#
# -> !reflect.DeepEqual(newPod, podWithoutEphemeralContainers())
#
#
# if tc.wantAllowInvalidPodDeletionCost != gotOptions.AllowInvalidPodDeletionCost {
# 				t.Errorf("unexpected diff, want: %v, got: %v", tc.wantAllowInvalidPodDeletionCost, gotOptions.AllowInvalidPodDeletionCost)
# 			}
#
#
# -> tc.wantAllowInvalidPodDeletionCost != gotOptions.AllowInvalidPodDeletionCost
#
#
# File :             ./kubernetes/pkg/api/v1/pod/util_test.go
#
#
#
# File :             ./kubernetes/pkg/api/persistentvolume/util_test.go
#
#
#
# File :             ./kubernetes/pkg/api/persistentvolumeclaim/util_test.go
#
#
#
# File :             ./kubernetes/pkg/api/podsecuritypolicy/util_test.go
#
#
#
# if !reflect.DeepEqual(oldPSPSpec, oldPSPSpecInfo.sc()) {
# 						t.Errorf("old PodSecurityPolicySpec changed: %v", cmp.Diff(oldPSPSpec, oldPSPSpecInfo.sc()))
# 					}
#
#
# -> !reflect.DeepEqual(oldPSPSpec, oldPSPSpecInfo.sc())
#
#
# if !reflect.DeepEqual(newPSPSpec, newPSPSpecInfo.sc()) {
# 							t.Errorf("new PodSecurityPolicySpec changed: %v", cmp.Diff(newPSPSpec, newPSPSpecInfo.sc()))
# 						}
#
#
# -> !reflect.DeepEqual(newPSPSpec, newPSPSpecInfo.sc())
#
#
# if reflect.DeepEqual(newPSPSpec, newPSPSpecInfo.sc()) {
# 							t.Errorf("new PodSecurityPolicySpec was not changed")
# 						}
#
#
# -> reflect.DeepEqual(newPSPSpec, newPSPSpecInfo.sc())
#
#
# if !reflect.DeepEqual(newPSPSpec, scWithoutAllowedProcMountTypes()) {
# 							t.Errorf("new PodSecurityPolicySpec had PodSecurityPolicySpecAllowedProcMountTypes: %v", cmp.Diff(newPSPSpec, scWithoutAllowedProcMountTypes()))
# 						}
#
#
# -> !reflect.DeepEqual(newPSPSpec, scWithoutAllowedProcMountTypes())
#
#
# if !reflect.DeepEqual(newPSPSpec, scWithoutAllowedProcMountTypes()) {
# 							t.Errorf("new PodSecurityPolicySpec had PodSecurityPolicySpecAllowedProcMountTypes: %v", cmp.Diff(newPSPSpec, scWithoutAllowedProcMountTypes()))
# 						}
#
#
# -> !reflect.DeepEqual(newPSPSpec, scWithoutAllowedProcMountTypes())
#
#
# if !reflect.DeepEqual(newPSPSpec, newPSPSpecInfo.sc()) {
# 							t.Errorf("new PodSecurityPolicySpec changed: %v", cmp.Diff(newPSPSpec, newPSPSpecInfo.sc()))
# 						}
#
#
# -> !reflect.DeepEqual(newPSPSpec, newPSPSpecInfo.sc())
#
#
# File :             ./kubernetes/pkg/proxy/topology_test.go
#
#
#
# File :             ./kubernetes/pkg/proxy/ipvs/proxier_test.go
#
#
#
# if tc.previousEndpoints[i] != nil {
# 				fp.OnEndpointSliceAdd(tc.previousEndpoints[i])
# 			}
#
#
# -> tc.previousEndpoints[i] != nil
#
#
# File :             ./kubernetes/pkg/proxy/iptables/proxier_test.go
#
#
#
# if tc.previousEndpoints[i] != nil {
# 				fp.OnEndpointSliceAdd(tc.previousEndpoints[i])
# 			}
#
#
# -> tc.previousEndpoints[i] != nil
#
#
# if tc.expectEndpointRule {
# 			fp.OnEndpointSliceDelete(endpointSlice)
# 			fp.syncProxyRules()
# 			assert.NotEqual(t, tc.expectedIPTablesWithSlice, fp.iptablesData.String())
# 		}
#
#
#
#
# File :             ./kubernetes/cmd/kube-controller-manager/app/plugins_providers.go
#
#
#
# File :             ./kubernetes/cmd/kubelet/app/server.go
#
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.MemoryQoS) &&
# 		!isCgroup2UnifiedMode() {
# 		klog.InfoS("Warning: MemoryQoS feature only works with cgroups v2 on Linux, but enabled with cgroups v1")
# 	}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.MemoryQoS) &&
# 		!isCgroup2UnifiedMode()
#
#
# if kubeDeps.ContainerManager == nil {
# 		if s.CgroupsPerQOS && s.CgroupRoot == "" {
# 			klog.InfoS("--cgroups-per-qos enabled, but --cgroup-root was not specified.  defaulting to /")
# 			s.CgroupRoot = "/"
# 		}
#
# 		machineInfo, err := kubeDeps.CAdvisorInterface.MachineInfo()
# 		if err != nil {
# 			return err
# 		}
# 		reservedSystemCPUs, err := getReservedCPUs(machineInfo, s.ReservedSystemCPUs)
# 		if err != nil {
# 			return err
# 		}
# 		if reservedSystemCPUs.Size() > 0 {
# 			// at cmd option validation phase it is tested either --system-reserved-cgroup or --kube-reserved-cgroup is specified, so overwrite should be ok
# 			klog.InfoS("Option --reserved-cpus is specified, it will overwrite the cpu setting in KubeReserved and SystemReserved", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 			if s.KubeReserved != nil {
# 				delete(s.KubeReserved, "cpu")
# 			}
# 			if s.SystemReserved == nil {
# 				s.SystemReserved = make(map[string]string)
# 			}
# 			s.SystemReserved["cpu"] = strconv.Itoa(reservedSystemCPUs.Size())
# 			klog.InfoS("After cpu setting is overwritten", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 		}
#
# 		kubeReserved, err := parseResourceList(s.KubeReserved)
# 		if err != nil {
# 			return err
# 		}
# 		systemReserved, err := parseResourceList(s.SystemReserved)
# 		if err != nil {
# 			return err
# 		}
# 		var hardEvictionThresholds []evictionapi.Threshold
# 		// If the user requested to ignore eviction thresholds, then do not set valid values for hardEvictionThresholds here.
# 		if !s.ExperimentalNodeAllocatableIgnoreEvictionThreshold {
# 			hardEvictionThresholds, err = eviction.ParseThresholdConfig([]string{}, s.EvictionHard, nil, nil, nil)
# 			if err != nil {
# 				return err
# 			}
# 		}
# 		experimentalQOSReserved, err := cm.ParseQOSReserved(s.QOSReserved)
# 		if err != nil {
# 			return err
# 		}
#
# 		devicePluginEnabled := utilfeature.DefaultFeatureGate.Enabled(features.DevicePlugins)
#
# 		var cpuManagerPolicyOptions map[string]string
# 		if utilfeature.DefaultFeatureGate.Enabled(features.CPUManager) {
# 			if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
# 		}
#
# 		kubeDeps.ContainerManager, err = cm.NewContainerManager(
# 			kubeDeps.Mounter,
# 			kubeDeps.CAdvisorInterface,
# 			cm.NodeConfig{
# 				RuntimeCgroupsName:    s.RuntimeCgroups,
# 				SystemCgroupsName:     s.SystemCgroups,
# 				KubeletCgroupsName:    s.KubeletCgroups,
# 				ContainerRuntime:      s.ContainerRuntime,
# 				CgroupsPerQOS:         s.CgroupsPerQOS,
# 				CgroupRoot:            s.CgroupRoot,
# 				CgroupDriver:          s.CgroupDriver,
# 				KubeletRootDir:        s.RootDirectory,
# 				ProtectKernelDefaults: s.ProtectKernelDefaults,
# 				NodeAllocatableConfig: cm.NodeAllocatableConfig{
# 					KubeReservedCgroupName:   s.KubeReservedCgroup,
# 					SystemReservedCgroupName: s.SystemReservedCgroup,
# 					EnforceNodeAllocatable:   sets.NewString(s.EnforceNodeAllocatable...),
# 					KubeReserved:             kubeReserved,
# 					SystemReserved:           systemReserved,
# 					ReservedSystemCPUs:       reservedSystemCPUs,
# 					HardEvictionThresholds:   hardEvictionThresholds,
# 				},
# 				QOSReserved:                             *experimentalQOSReserved,
# 				ExperimentalCPUManagerPolicy:            s.CPUManagerPolicy,
# 				ExperimentalCPUManagerPolicyOptions:     cpuManagerPolicyOptions,
# 				ExperimentalCPUManagerReconcilePeriod:   s.CPUManagerReconcilePeriod.Duration,
# 				ExperimentalMemoryManagerPolicy:         s.MemoryManagerPolicy,
# 				ExperimentalMemoryManagerReservedMemory: s.ReservedMemory,
# 				ExperimentalPodPidsLimit:                s.PodPidsLimit,
# 				EnforceCPULimits:                        s.CPUCFSQuota,
# 				CPUCFSQuotaPeriod:                       s.CPUCFSQuotaPeriod.Duration,
# 				ExperimentalTopologyManagerPolicy:       s.TopologyManagerPolicy,
# 				ExperimentalTopologyManagerScope:        s.TopologyManagerScope,
# 			},
# 			s.FailSwapOn,
# 			devicePluginEnabled,
# 			kubeDeps.Recorder)
#
# 		if err != nil {
# 			return err
# 		}
# 	}
#
#
# -> kubeDeps.ContainerManager == nil
#
#
# if kubeDeps.ContainerManager == nil {
# 		if s.CgroupsPerQOS && s.CgroupRoot == "" {
# 			klog.InfoS("--cgroups-per-qos enabled, but --cgroup-root was not specified.  defaulting to /")
# 			s.CgroupRoot = "/"
# 		}
#
# 		machineInfo, err := kubeDeps.CAdvisorInterface.MachineInfo()
# 		if err != nil {
# 			return err
# 		}
# 		reservedSystemCPUs, err := getReservedCPUs(machineInfo, s.ReservedSystemCPUs)
# 		if err != nil {
# 			return err
# 		}
# 		if reservedSystemCPUs.Size() > 0 {
# 			// at cmd option validation phase it is tested either --system-reserved-cgroup or --kube-reserved-cgroup is specified, so overwrite should be ok
# ...
# 			}
# 			s.SystemReserved["cpu"] = strconv.Itoa(reservedSystemCPUs.Size())
# 			klog.InfoS("After cpu setting is overwritten", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 		}
#
# 		kubeReserved, err := parseResourceList(s.KubeReserved)
# 		if err != nil {
# 			return err
# 		}
# 		systemReserved, err := parseResourceList(s.SystemReserved)
# 		if err != nil {
# 			return err
# 		}
# 		var hardEvictionThresholds []evictionapi.Threshold
# 		// If the user requested to ignore eviction thresholds, then do not set valid values for hardEvictionThresholds here.
# 		if !s.ExperimentalNodeAllocatableIgnoreEvictionThreshold {
# 			hardEvictionThresholds, err = eviction.ParseThresholdConfig([]string{}, s.EvictionHard, nil, nil, nil)
# 			if err != nil {
# 				return err
# 			}
# 		}
# 		experimentalQOSReserved, err := cm.ParseQOSReserved(s.QOSReserved)
# 		if err != nil {
# 			return err
# 		}
#
# 		devicePluginEnabled := utilfeature.DefaultFeatureGate.Enabled(features.DevicePlugins)
#
# 		var cpuManagerPolicyOptions map[string]string
# 		if utilfeature.DefaultFeatureGate.Enabled(features.CPUManager) {
# 			if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
# 		}
#
# 		kubeDeps.ContainerManager, err = cm.NewContainerManager(
# 			kubeDeps.Mounter,
# 			kubeDeps.CAdvisorInterface,
# 			cm.NodeConfig{
# 				RuntimeCgroupsName:    s.RuntimeCgroups,
# 				SystemCgroupsName:     s.SystemCgroups,
# 				KubeletCgroupsName:    s.KubeletCgroups,
# 				ContainerRuntime:      s.ContainerRuntime,
# 				CgroupsPerQOS:         s.CgroupsPerQOS,
# 				CgroupRoot:            s.CgroupRoot,
# 				CgroupDriver:          s.CgroupDriver,
# 				KubeletRootDir:        s.RootDirectory,
# 				ProtectKernelDefaults: s.ProtectKernelDefaults,
# 				NodeAllocatableConfig: cm.NodeAllocatableConfig{
# 					KubeReservedCgroupName:   s.KubeReservedCgroup,
# 					SystemReservedCgroupName: s.SystemReservedCgroup,
# 					EnforceNodeAllocatable:   sets.NewString(s.EnforceNodeAllocatable...),
# 					KubeReserved:             kubeReserved,
# 					SystemReserved:           systemReserved,
# 					ReservedSystemCPUs:       reservedSystemCPUs,
# 					HardEvictionThresholds:   hardEvictionThresholds,
# 				},
# 				QOSReserved:                             *experimentalQOSReserved,
# 				ExperimentalCPUManagerPolicy:            s.CPUManagerPolicy,
# 				ExperimentalCPUManagerPolicyOptions:     cpuManagerPolicyOptions,
# 				ExperimentalCPUManagerReconcilePeriod:   s.CPUManagerReconcilePeriod.Duration,
# 				ExperimentalMemoryManagerPolicy:         s.MemoryManagerPolicy,
# 				ExperimentalMemoryManagerReservedMemory: s.ReservedMemory,
# 				ExperimentalPodPidsLimit:                s.PodPidsLimit,
# 				EnforceCPULimits:                        s.CPUCFSQuota,
# 				CPUCFSQuotaPeriod:                       s.CPUCFSQuotaPeriod.Duration,
# 				ExperimentalTopologyManagerPolicy:       s.TopologyManagerPolicy,
# 				ExperimentalTopologyManagerScope:        s.TopologyManagerScope,
# 			},
# 			s.FailSwapOn,
# 			devicePluginEnabled,
# 			kubeDeps.Recorder)
#
# 		if err != nil {
# 			return err
# 		}
# 	}
#
#
# -> kubeDeps.ContainerManager == nil
#
#
# if kubeDeps.ContainerManager == nil {
# 		if s.CgroupsPerQOS && s.CgroupRoot == "" {
# 			klog.InfoS("--cgroups-per-qos enabled, but --cgroup-root was not specified.  defaulting to /")
# 			s.CgroupRoot = "/"
# 		}
#
# 		machineInfo, err := kubeDeps.CAdvisorInterface.MachineInfo()
# 		if err != nil {
# 			return err
# 		}
# 		reservedSystemCPUs, err := getReservedCPUs(machineInfo, s.ReservedSystemCPUs)
# 		if err != nil {
# 			return err
# 		}
# 		if reservedSystemCPUs.Size() > 0 {
# 			// at cmd option validation phase it is tested either --system-reserved-cgroup or --kube-reserved-cgroup is specified, so overwrite should be ok
# 			klog.InfoS("Option --reserved-cpus is specified, it will overwrite the cpu setting in KubeReserved and SystemReserved", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 			if s.KubeReserved != nil {
# 				delete(s.KubeReserved, "cpu")
# 			}
# 			if s.SystemReserved == nil {
# 				s.SystemReserved = make(map[string]string)
# 			}
# 			s.SystemReserved["cpu"] = strconv.Itoa(reservedSystemCPUs.Size())
# 			klog.InfoS("After cpu setting is overwritten", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 		}
#
# 		kubeReserved, err := parseResourceList(s.KubeReserved)
# 		if err != nil {
# 			return err
# 		}
# 		systemReserved, err := parseResourceList(s.SystemReserved)
# 		if err != nil {
# 			return err
# 		}
# 		var hardEvictionThresholds []evictionapi.Threshold
# 		// If the user requested to ignore eviction thresholds, then do not set valid values for hardEvictionThresholds here.
# 		if !s.ExperimentalNodeAllocatableIgnoreEvictionThreshold {
# 			hardEvictionThresholds, err = eviction.ParseThresholdConfig([]string{}, s.EvictionHard, nil, nil, nil)
# 			if err != nil {
# 				return err
# 			}
# 		}
# 		experimentalQOSReserved, err := cm.ParseQOSReserved(s.QOSReserved)
# 		if err != nil {
# 			return err
# 		}
#
# 		devicePluginEnabled := utilfeature.DefaultFeatureGate.Enabled(features.DevicePlugins)
#
# 		var cpuManagerPolicyOptions map[string]string
# 		if utilfeature.DefaultFeatureGate.Enabled(features.CPUManager) {
# 			if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
# 		}
#
# 		kubeDeps.ContainerManager, err = cm.NewContainerManager(
# 			kubeDeps.Mounter,
# 			kubeDeps.CAdvisorInterface,
# 			cm.NodeConfig{
# 				RuntimeCgroupsName:    s.RuntimeCgroups,
# 				SystemCgroupsName:     s.SystemCgroups,
# 				KubeletCgroupsName:    s.KubeletCgroups,
# 				ContainerRuntime:      s.ContainerRuntime,
# 				CgroupsPerQOS:         s.CgroupsPerQOS,
# 				CgroupRoot:            s.CgroupRoot,
# 				CgroupDriver:          s.CgroupDriver,
# 				KubeletRootDir:        s.RootDirectory,
# 				ProtectKernelDefaults: s.ProtectKernelDefaults,
# 				NodeAllocatableConfig: cm.NodeAllocatableConfig{
# 					KubeReservedCgroupName:   s.KubeReservedCgroup,
# 					SystemReservedCgroupName: s.SystemReservedCgroup,
# 					EnforceNodeAllocatable:   sets.NewString(s.EnforceNodeAllocatable...),
# 					KubeReserved:             kubeReserved,
# 					SystemReserved:           systemReserved,
# 					ReservedSystemCPUs:       reservedSystemCPUs,
# 					HardEvictionThresholds:   hardEvictionThresholds,
# 				},
# 				QOSReserved:                             *experimentalQOSReserved,
# 				ExperimentalCPUManagerPolicy:            s.CPUManagerPolicy,
# 				ExperimentalCPUManagerPolicyOptions:     cpuManagerPolicyOptions,
# 				ExperimentalCPUManagerReconcilePeriod:   s.CPUManagerReconcilePeriod.Duration,
# 				ExperimentalMemoryManagerPolicy:         s.MemoryManagerPolicy,
# 				ExperimentalMemoryManagerReservedMemory: s.ReservedMemory,
# 				ExperimentalPodPidsLimit:                s.PodPidsLimit,
# 				EnforceCPULimits:                        s.CPUCFSQuota,
# 				CPUCFSQuotaPeriod:                       s.CPUCFSQuotaPeriod.Duration,
# 				ExperimentalTopologyManagerPolicy:       s.TopologyManagerPolicy,
# 				ExperimentalTopologyManagerScope:        s.TopologyManagerScope,
# 			},
# 			s.FailSwapOn,
# 			devicePluginEnabled,
# 			kubeDeps.Recorder)
#
# 		if err != nil {
# 			return err
# 		}
# 	}
#
#
# -> kubeDeps.ContainerManager == nil
#
#
# if kubeDeps.ContainerManager == nil {
# 		if s.CgroupsPerQOS && s.CgroupRoot == "" {
# 			klog.InfoS("--cgroups-per-qos enabled, but --cgroup-root was not specified.  defaulting to /")
# 			s.CgroupRoot = "/"
# 		}
#
# 		machineInfo, err := kubeDeps.CAdvisorInterface.MachineInfo()
# 		if err != nil {
# 			return err
# 		}
# 		reservedSystemCPUs, err := getReservedCPUs(machineInfo, s.ReservedSystemCPUs)
# 		if err != nil {
# 			return err
# 		}
# 		if reservedSystemCPUs.Size() > 0 {
# 			// at cmd option validation phase it is tested either --system-reserved-cgroup or --kube-reserved-cgroup is specified, so overwrite should be ok
# 			klog.InfoS("Option --reserved-cpus is specified, it will overwrite the cpu setting in KubeReserved and SystemReserved", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 			if s.KubeReserved != nil {
# 				delete(s.KubeReserved, "cpu")
# 			}
# 			if s.SystemReserved == nil {
# 				s.SystemReserved = make(map[string]string)
# 			}
# 			s.SystemReserved["cpu"] = strconv.Itoa(reservedSystemCPUs.Size())
# 			klog.InfoS("After cpu setting is overwritten", "kubeReservedCPUs", s.KubeReserved, "systemReservedCPUs", s.SystemReserved)
# 		}
#
# 		kubeReserved, err := parseResourceList(s.KubeReserved)
# 		if err != nil {
# 			return err
# 		}
# 		systemReserved, err := parseResourceList(s.SystemReserved)
# 		if err != nil {
# 			return err
# 		}
# 		var hardEvictionThresholds []evictionapi.Threshold
# 		// If the user requested to ignore eviction thresholds, then do not set valid values for hardEvictionThresholds here.
# 		if !s.ExperimentalNodeAllocatableIgnoreEvictionThreshold {
# 			hardEvictionThresholds, err = eviction.ParseThresholdConfig([]string{}, s.EvictionHard, nil, nil, nil)
# 			if err != nil {
# 				return err
# 			}
# 		}
# 		experimentalQOSReserved, err := cm.ParseQOSReserved(s.QOSReserved)
# 		if err != nil {
# 			return err
# 		}
#
# 		devicePluginEnabled := utilfeature.DefaultFeatureGate.Enabled(features.DevicePlugins)
#
# 		var cpuManagerPolicyOptions map[string]string
# 		if utilfeature.DefaultFeatureGate.Enabled(features.CPUManager) {
# 			if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
# 		}
#
# 		kubeDeps.ContainerManager, err = cm.NewContainerManager(
# 			kubeDeps.Mounter,
# 			kubeDeps.CAdvisorInterface,
# 			cm.NodeConfig{
# 				RuntimeCgroupsName:    s.RuntimeCgroups,
# 				SystemCgroupsName:     s.SystemCgroups,
# 				KubeletCgroupsName:    s.KubeletCgroups,
# 				ContainerRuntime:      s.ContainerRuntime,
# 				CgroupsPerQOS:         s.CgroupsPerQOS,
# 				CgroupRoot:            s.CgroupRoot,
# 				CgroupDriver:          s.CgroupDriver,
# 				KubeletRootDir:        s.RootDirectory,
# 				ProtectKernelDefaults: s.ProtectKernelDefaults,
# 				NodeAllocatableConfig: cm.NodeAllocatableConfig{
# 					KubeReservedCgroupName:   s.KubeReservedCgroup,
# 					SystemReservedCgroupName: s.SystemReservedCgroup,
# 					EnforceNodeAllocatable:   sets.NewString(s.EnforceNodeAllocatable...),
# 					KubeReserved:             kubeReserved,
# 					SystemReserved:           systemReserved,
# 					ReservedSystemCPUs:       reservedSystemCPUs,
# 					HardEvictionThresholds:   hardEvictionThresholds,
# 				},
# 				QOSReserved:                             *experimentalQOSReserved,
# 				ExperimentalCPUManagerPolicy:            s.CPUManagerPolicy,
# 				ExperimentalCPUManagerPolicyOptions:     cpuManagerPolicyOptions,
# 				ExperimentalCPUManagerReconcilePeriod:   s.CPUManagerReconcilePeriod.Duration,
# 				ExperimentalMemoryManagerPolicy:         s.MemoryManagerPolicy,
# 				ExperimentalMemoryManagerReservedMemory: s.ReservedMemory,
# 				ExperimentalPodPidsLimit:                s.PodPidsLimit,
# 				EnforceCPULimits:                        s.CPUCFSQuota,
# 				CPUCFSQuotaPeriod:                       s.CPUCFSQuotaPeriod.Duration,
# 				ExperimentalTopologyManagerPolicy:       s.TopologyManagerPolicy,
# 				ExperimentalTopologyManagerScope:        s.TopologyManagerScope,
# 			},
# 			s.FailSwapOn,
# 			devicePluginEnabled,
# 			kubeDeps.Recorder)
#
# 		if err != nil {
# 			return err
# 		}
# 	}
#
#
# -> kubeDeps.ContainerManager == nil
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.CPUManager) {
# 			if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
# 		}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.CPUManager)
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.CPUManager) {
# 			if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
# 		}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.CPUManager)
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions)
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions) {
# 				cpuManagerPolicyOptions = s.CPUManagerPolicyOptions
# 			} else if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.CPUManagerPolicyOptions)
#
#
# if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
#
#
# -> s.CPUManagerPolicyOptions != nil
#
#
# if s.CPUManagerPolicyOptions != nil {
# 				return fmt.Errorf("CPU Manager policy options %v require feature gates %q, %q enabled",
# 					s.CPUManagerPolicyOptions, features.CPUManager, features.CPUManagerPolicyOptions)
# 			}
#
#
# -> s.CPUManagerPolicyOptions != nil
# if utilfeature.DefaultFeatureGate.Enabled(features.DynamicKubeletConfig) && len(s.DynamicConfigDir.Value()) > 0 &&
# 		kubeDeps.KubeletConfigController != nil && !standaloneMode && !s.RunOnce {
# 		if err := kubeDeps.KubeletConfigController.StartSync(kubeDeps.KubeClient, kubeDeps.EventClient, string(nodeName)); err != nil {
# 			return err
# 		}
# 	}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.DynamicKubeletConfig) && len(s.DynamicConfigDir.Value()) > 0 &&
# 		kubeDeps.KubeletConfigController != nil && !standaloneMode && !s.RunOnce
#
#
# if kubeServer.KubeletConfiguration.SeccompDefault && !utilfeature.DefaultFeatureGate.Enabled(features.SeccompDefault) {
# 		return fmt.Errorf("the SeccompDefault feature gate must be enabled in order to use the SeccompDefault configuration")
# 	}
#
#
# -> kubeServer.KubeletConfiguration.SeccompDefault && !utilfeature.DefaultFeatureGate.Enabled(features.SeccompDefault)
#
#
# if utilfeature.DefaultFeatureGate.Enabled(features.KubeletPodResources) {
# 		go k.ListenAndServePodResources()
# 	}
#
#
# -> utilfeature.DefaultFeatureGate.Enabled(features.KubeletPodResources)
#
#
# if !utilfeature.DefaultFeatureGate.Enabled(features.DynamicKubeletConfig) {
# 		return nil, nil, fmt.Errorf("failed to bootstrap Kubelet config controller, you must enable the DynamicKubeletConfig feature gate")
# 	}
#
#
# -> !utilfeature.DefaultFeatureGate.Enabled(features.DynamicKubeletConfig)
#
#
# File :             ./kubernetes/cmd/kubelet/app/plugins_providers.go
#
#
#
# File :             ./kubernetes/cmd/kube-scheduler/app/server_test.go
#
#
#
# File :             ./kubernetes/cmd/kubeadm/app/features/features.go
